# %% [markdown]
# # Project 5 - Optimization Exercise
#
# ## finding N maximally distant points on a sphere or unit sphere

# %%
import tensorflow as tf
assert tf.__version__ >= "2.0"

import numpy as np
import matplotlib.pyplot as plt
import random

# %matplotlib qt

# %%
# set up number of dimensions (could be 2 or 3 for visualization)
NUM_DIMS = 3

# set up number of points that will be on unit sphere
NUM_PTS = 8

# %%
# function to calculate loss term that penalizes points for not being on unit sphere

def sphere_term(tf_pts):           #tf_points will be defined later. It's a tensorflow variable. Basically an array of points.
    zr = np.zeros([NUM_DIMS])      #make the Origin. We want all points to be 1 unit away from that. (on the unit sphere)
    a = 0                          #our distance from the origin. To be calculted in the next few lines.
    for n in range(NUM_PTS):
        a += tf.abs(tf.norm(tf_pts[n,:]-zr)-1)
        
        #Basically takes a vector difference of the point and origin, than computes the norm (magniture)
        #before taking the absolute value. The norm should be 1, so we subtract 1 to try and get 0, which
        #should be the lowest possible value to get out of this function.
        
    return a

# %%
#takes a point input, which is what the function will attempt to cause 1 point to "gravitate" towards. The cost rises as the
#first point in the input list gets further from the chosen point. (I'm using Euclidian distance for this)

def point_term(tf_pts, point):
    a = 0
    value_array = tf_pts.numpy()#convert to a numpy array for ease of slicing and striding. Inefficiant? Yes. Effective though.
    counter = 0
    
    #iterate over each vector value, find the difference between them, and square the result.
    
    for i in range(0, len(value_array[0])):
            counter += (value_array[0][i] - point[i])**2
    euclidian_distance = counter**1/2
    return euclidian_distance

# %%
#testing and gaining intuition for the "norm" of different things.
origin = np.array([0.0, 0.0])
inside = np.array([0.5, 0.6])
on = np.array([1.0, 0.0])
outside = np.array([1.5, 2.0])
big = [[3.0, 2.0], [0.3, 0.2], [1.0, 0.0]]

on_norm = tf.norm(on)
print("on_norm is: " + str(on_norm))

on_minus_origin = (on - origin)
print("on_minus_origin is: " + str(on_minus_origin))

origin_minus_on = (origin - on)
print("origin_minus_on is: " + str(origin_minus_on))

origin_minus_on_norm = tf.norm(origin_minus_on)
print("origin_minus_on_norm is: " + str(origin_minus_on_norm))

inside_norm = tf.norm(inside)
print("inside_norm is: " + str(inside_norm))

big_norm = tf.norm(big)
print("big_norm is: " + str(big_norm))

#OK if we can get norms that are less than 1 than our function might converge on something wrong. TODO
# Out:
# on_norm is: tf.Tensor(1.0, shape=(), dtype=float64)
# on_minus_origin is: [1. 0.]
# origin_minus_on is: [-1.  0.]
# origin_minus_on_norm is: tf.Tensor(1.0, shape=(), dtype=float64)
# inside_norm is: tf.Tensor(0.7810249675906654, shape=(), dtype=float64)
# big_norm is: tf.Tensor(3.7589893, shape=(), dtype=float32)

# %%
# function to calculate loss term that penalizes points for not being on unit sphere
def repel_term(tf_pts):
    a = 0
    for n in range(NUM_PTS):
        for m in range(n):
            a += 1.0/(tf.norm(tf_pts[n,:]-tf_pts[m,:])+1e-20)
    return a

# %%
# combined loss function with term weight constants
alpha = 10
beta = 10
gamma = 1000 #100

close_point = np.zeros(NUM_DIMS) #the point to try and get the first point in tf_pts to gravitate to. Can be any dimensionality.
close_point[-1] = -1 #make the last value in close_point be a 1.

# `loss` is a callable that takes no argument and returns the value to minimize.
# "lambda" is a tensorflow compatibility step for the loss callable.

loss = lambda: alpha*sphere_term(tf_pts) + beta*repel_term(tf_pts) + gamma*point_term(tf_pts, close_point)

# %%
# Create an optimizer with the desired parameters.
# opt = tf.keras.optimizers.SGD(learning_rate=0.00001)
opt = tf.keras.optimizers.Nadam()#instantiate an instance of the nadam optimizer and call it "opt"

# %%
#create random points in range 0-1.0 as numpy array and cast to TF variable
tf_pts = tf.Variable(np.random.rand(NUM_PTS,NUM_DIMS))

# %%
# calling optimization in tensorflow
# set up number of iterations that the optimization will run
NUM_ITERS = 10000 # 100000
sphere_terms = []#make two lists for holding the cost information as we go along. We'll use it later.
repel_terms = []
point_terms = []
for n in range(NUM_ITERS):
    sphere_terms.append(alpha*sphere_term(tf_pts))
    repel_terms.append(beta*repel_term(tf_pts))   
    point_terms.append(gamma*point_term(tf_pts, close_point))
    if n%100 == 0:
        print('iteration #: ',n)#print every hundredth iteration.
        print(alpha*sphere_term(tf_pts))
        print(beta*repel_term(tf_pts))
    opt.minimize(loss, var_list=[tf_pts])
# Out:
# iteration #:  0
# tf.Tensor(11.838378008825003, shape=(), dtype=float64)
# tf.Tensor(423.895837728231, shape=(), dtype=float64)
# iteration #:  100
# tf.Tensor(16.46330400464222, shape=(), dtype=float64)
# tf.Tensor(330.271255463761, shape=(), dtype=float64)
# iteration #:  200
# tf.Tensor(19.947482912792644, shape=(), dtype=float64)
# tf.Tensor(278.81266914933735, shape=(), dtype=float64)
# iteration #:  300
# tf.Tensor(21.50125425536097, shape=(), dtype=float64)
# tf.Tensor(243.8066537472073, shape=(), dtype=float64)
# iteration #:  400
# tf.Tensor(24.88044382773517, shape=(), dtype=float64)
# tf.Tensor(219.46781888501548, shape=(), dtype=float64)
# iteration #:  500
# tf.Tensor(28.050554112783132, shape=(), dtype=float64)
# tf.Tensor(201.12354769975195, shape=(), dtype=float64)
# iteration #:  600
# tf.Tensor(30.837796791276926, shape=(), dtype=float64)
# tf.Tensor(186.7979439768138, shape=(), dtype=float64)
# iteration #:  700
# tf.Tensor(33.18089172462288, shape=(), dtype=float64)
# tf.Tensor(175.3861802678264, shape=(), dtype=float64)
# iteration #:  800
# tf.Tensor(35.07966514616195, shape=(), dtype=float64)
# tf.Tensor(166.14849508566184, shape=(), dtype=float64)
# iteration #:  900
# tf.Tensor(36.55463132272787, shape=(), dtype=float64)
# tf.Tensor(158.5669857911364, shape=(), dtype=float64)
# iteration #:  1000
# tf.Tensor(37.63079111114757, shape=(), dtype=float64)
# tf.Tensor(152.27260887403548, shape=(), dtype=float64)
# iteration #:  1100
# tf.Tensor(38.33267683371933, shape=(), dtype=float64)
# tf.Tensor(146.99796006367202, shape=(), dtype=float64)
# iteration #:  1200
# tf.Tensor(39.07859148496818, shape=(), dtype=float64)
# tf.Tensor(142.83051651206418, shape=(), dtype=float64)
# iteration #:  1300
# tf.Tensor(40.26061265135259, shape=(), dtype=float64)
# tf.Tensor(139.97176039359636, shape=(), dtype=float64)
# iteration #:  1400
# tf.Tensor(41.29207265674041, shape=(), dtype=float64)
# tf.Tensor(137.56191257318153, shape=(), dtype=float64)
# iteration #:  1500
# tf.Tensor(42.17955633203392, shape=(), dtype=float64)
# tf.Tensor(135.53183393446633, shape=(), dtype=float64)
# iteration #:  1600
# tf.Tensor(42.93154248461016, shape=(), dtype=float64)
# tf.Tensor(133.82506434922647, shape=(), dtype=float64)
# iteration #:  1700
# tf.Tensor(43.55869173740126, shape=(), dtype=float64)
# tf.Tensor(132.39384592363874, shape=(), dtype=float64)
# iteration #:  1800
# tf.Tensor(44.07293840017549, shape=(), dtype=float64)
# tf.Tensor(131.1973948105363, shape=(), dtype=float64)
# iteration #:  1900
# tf.Tensor(44.48678525865043, shape=(), dtype=float64)
# tf.Tensor(130.20062185767446, shape=(), dtype=float64)
# iteration #:  2000
# tf.Tensor(44.812756260961464, shape=(), dtype=float64)
# tf.Tensor(129.37318306885732, shape=(), dtype=float64)
# iteration #:  2100
# tf.Tensor(45.07983921670862, shape=(), dtype=float64)
# tf.Tensor(128.67231344098434, shape=(), dtype=float64)
# iteration #:  2200
# tf.Tensor(45.27920896403478, shape=(), dtype=float64)
# tf.Tensor(128.09522191530039, shape=(), dtype=float64)
# iteration #:  2300
# tf.Tensor(45.42097814345961, shape=(), dtype=float64)
# tf.Tensor(127.62264926786303, shape=(), dtype=float64)
# iteration #:  2400
# tf.Tensor(45.528326599476266, shape=(), dtype=float64)
# tf.Tensor(127.22419673510319, shape=(), dtype=float64)
# iteration #:  2500
# tf.Tensor(45.59181079805792, shape=(), dtype=float64)
# tf.Tensor(126.90278116738435, shape=(), dtype=float64)
# iteration #:  2600
# tf.Tensor(45.64038597053829, shape=(), dtype=float64)
# tf.Tensor(126.62502558981626, shape=(), dtype=float64)
# iteration #:  2700
# tf.Tensor(45.64518854487563, shape=(), dtype=float64)
# tf.Tensor(126.41457409202027, shape=(), dtype=float64)
# iteration #:  2800
# tf.Tensor(45.66112514897286, shape=(), dtype=float64)
# tf.Tensor(126.21488772342934, shape=(), dtype=float64)
# iteration #:  2900
# tf.Tensor(45.6555289336361, shape=(), dtype=float64)
# tf.Tensor(126.05459624720389, shape=(), dtype=float64)
# iteration #:  3000
# tf.Tensor(45.6257956539568, shape=(), dtype=float64)
# tf.Tensor(125.93361980708661, shape=(), dtype=float64)
# iteration #:  3100
# tf.Tensor(45.602136557854244, shape=(), dtype=float64)
# tf.Tensor(125.82118958328918, shape=(), dtype=float64)
# iteration #:  3200
# tf.Tensor(45.557999775392794, shape=(), dtype=float64)
# tf.Tensor(125.74083089394648, shape=(), dtype=float64)
# iteration #:  3300
# tf.Tensor(45.49663355206896, shape=(), dtype=float64)
# tf.Tensor(125.68788838189624, shape=(), dtype=float64)
# iteration #:  3400
# tf.Tensor(45.43916987723577, shape=(), dtype=float64)
# tf.Tensor(125.64105719085711, shape=(), dtype=float64)
# iteration #:  3500
# tf.Tensor(45.370274088209456, shape=(), dtype=float64)
# tf.Tensor(125.61341777988989, shape=(), dtype=float64)
# iteration #:  3600
# tf.Tensor(45.30883834907293, shape=(), dtype=float64)
# tf.Tensor(125.5857242952685, shape=(), dtype=float64)
# iteration #:  3700
# tf.Tensor(45.22453926713331, shape=(), dtype=float64)
# tf.Tensor(125.58475097347312, shape=(), dtype=float64)
# iteration #:  3800
# tf.Tensor(45.12063437198879, shape=(), dtype=float64)
# tf.Tensor(125.60533520054958, shape=(), dtype=float64)
# iteration #:  3900
# tf.Tensor(45.14507615671117, shape=(), dtype=float64)
# tf.Tensor(125.50692568891088, shape=(), dtype=float64)
# iteration #:  4000
# tf.Tensor(45.47796414663013, shape=(), dtype=float64)
# tf.Tensor(125.13403140473159, shape=(), dtype=float64)
# iteration #:  4100
# tf.Tensor(45.70145943373275, shape=(), dtype=float64)
# tf.Tensor(124.8784096052687, shape=(), dtype=float64)
# iteration #:  4200
# tf.Tensor(45.80800604268397, shape=(), dtype=float64)
# tf.Tensor(124.74203370885135, shape=(), dtype=float64)
# iteration #:  4300
# tf.Tensor(45.92996435881952, shape=(), dtype=float64)
# tf.Tensor(124.59971899650951, shape=(), dtype=float64)
# iteration #:  4400
# tf.Tensor(45.98170111184558, shape=(), dtype=float64)
# tf.Tensor(124.52789161964259, shape=(), dtype=float64)
# iteration #:  4500
# tf.Tensor(46.03854011869443, shape=(), dtype=float64)
# tf.Tensor(124.45633851479928, shape=(), dtype=float64)
# iteration #:  4600
# tf.Tensor(46.08568455174044, shape=(), dtype=float64)
# tf.Tensor(124.39718696037562, shape=(), dtype=float64)
# iteration #:  4700
# tf.Tensor(46.07677991820105, shape=(), dtype=float64)
# tf.Tensor(124.39182173686291, shape=(), dtype=float64)
# iteration #:  4800
# tf.Tensor(46.09039597149682, shape=(), dtype=float64)
# tf.Tensor(124.36853437914198, shape=(), dtype=float64)
# iteration #:  4900
# tf.Tensor(46.12176720462102, shape=(), dtype=float64)
# tf.Tensor(124.33085442358416, shape=(), dtype=float64)
# iteration #:  5000
# tf.Tensor(46.11959336594117, shape=(), dtype=float64)
# tf.Tensor(124.32514405761782, shape=(), dtype=float64)
# iteration #:  5100
# tf.Tensor(46.10769500960184, shape=(), dtype=float64)
# tf.Tensor(124.33350100170495, shape=(), dtype=float64)
# iteration #:  5200
# tf.Tensor(46.10030789889025, shape=(), dtype=float64)
# tf.Tensor(124.33037070886868, shape=(), dtype=float64)
# iteration #:  5300
# tf.Tensor(46.129935480112934, shape=(), dtype=float64)
# tf.Tensor(124.29874728072687, shape=(), dtype=float64)
# iteration #:  5400
# tf.Tensor(46.142620619725996, shape=(), dtype=float64)
# tf.Tensor(124.2831374470069, shape=(), dtype=float64)
# iteration #:  5500
# tf.Tensor(46.09952224623896, shape=(), dtype=float64)
# tf.Tensor(124.32293757634523, shape=(), dtype=float64)
# iteration #:  5600
# tf.Tensor(46.124973678679346, shape=(), dtype=float64)
# tf.Tensor(124.29262856730003, shape=(), dtype=float64)
# iteration #:  5700
# tf.Tensor(46.14582355059767, shape=(), dtype=float64)
# tf.Tensor(124.27114167178243, shape=(), dtype=float64)
# iteration #:  5800
# tf.Tensor(46.14646951337012, shape=(), dtype=float64)
# tf.Tensor(124.2684329817588, shape=(), dtype=float64)
# iteration #:  5900
# tf.Tensor(46.13830404746324, shape=(), dtype=float64)
# tf.Tensor(124.27398128877492, shape=(), dtype=float64)
# iteration #:  6000
# tf.Tensor(46.13186423326432, shape=(), dtype=float64)
# tf.Tensor(124.27813174865031, shape=(), dtype=float64)
# iteration #:  6100
# tf.Tensor(46.1461597810039, shape=(), dtype=float64)
# tf.Tensor(124.26379942418286, shape=(), dtype=float64)
# iteration #:  6200
# tf.Tensor(46.13323020888453, shape=(), dtype=float64)
# tf.Tensor(124.27437123050933, shape=(), dtype=float64)
# iteration #:  6300
# tf.Tensor(46.15502859275567, shape=(), dtype=float64)
# tf.Tensor(124.25361639291368, shape=(), dtype=float64)
# iteration #:  6400
# tf.Tensor(46.167452459574974, shape=(), dtype=float64)
# tf.Tensor(124.24149904232755, shape=(), dtype=float64)
# iteration #:  6500
# tf.Tensor(46.16402590284116, shape=(), dtype=float64)
# tf.Tensor(124.2438023634391, shape=(), dtype=float64)
# iteration #:  6600
# tf.Tensor(46.15181398653949, shape=(), dtype=float64)
# tf.Tensor(124.25424015873182, shape=(), dtype=float64)
# iteration #:  6700
# tf.Tensor(46.14917117462919, shape=(), dtype=float64)
# tf.Tensor(124.25604073696064, shape=(), dtype=float64)
# iteration #:  6800
# tf.Tensor(46.158018225106204, shape=(), dtype=float64)
# tf.Tensor(124.24760176796418, shape=(), dtype=float64)
# iteration #:  6900
# tf.Tensor(46.142852387784394, shape=(), dtype=float64)
# tf.Tensor(124.26100206414132, shape=(), dtype=float64)
# iteration #:  7000
# tf.Tensor(46.162224258084976, shape=(), dtype=float64)
# tf.Tensor(124.2430464212259, shape=(), dtype=float64)
# iteration #:  7100
# tf.Tensor(46.16910716358465, shape=(), dtype=float64)
# tf.Tensor(124.23653052636674, shape=(), dtype=float64)
# iteration #:  7200
# tf.Tensor(46.16828383608903, shape=(), dtype=float64)
# tf.Tensor(124.23694969198769, shape=(), dtype=float64)
# iteration #:  7300
# tf.Tensor(46.130851083582805, shape=(), dtype=float64)
# tf.Tensor(124.27072913912696, shape=(), dtype=float64)
# iteration #:  7400
# tf.Tensor(46.152113741464824, shape=(), dtype=float64)
# tf.Tensor(124.25127115012806, shape=(), dtype=float64)
# iteration #:  7500
# tf.Tensor(46.167583609797035, shape=(), dtype=float64)
# tf.Tensor(124.23699008606356, shape=(), dtype=float64)
# iteration #:  7600
# tf.Tensor(46.16996500101118, shape=(), dtype=float64)
# tf.Tensor(124.23473491488552, shape=(), dtype=float64)
# iteration #:  7700
# tf.Tensor(46.15297831700245, shape=(), dtype=float64)
# tf.Tensor(124.25007931863271, shape=(), dtype=float64)
# iteration #:  7800
# tf.Tensor(46.15870488110647, shape=(), dtype=float64)
# tf.Tensor(124.24490788493208, shape=(), dtype=float64)
# iteration #:  7900
# tf.Tensor(46.152384086994395, shape=(), dtype=float64)
# tf.Tensor(124.25057992431283, shape=(), dtype=float64)
# iteration #:  8000
# tf.Tensor(46.16492219360726, shape=(), dtype=float64)
# tf.Tensor(124.23907479207726, shape=(), dtype=float64)
# iteration #:  8100
# tf.Tensor(46.14878470802349, shape=(), dtype=float64)
# tf.Tensor(124.25363184537652, shape=(), dtype=float64)
# iteration #:  8200
# tf.Tensor(46.16313848375487, shape=(), dtype=float64)
# tf.Tensor(124.24058915497744, shape=(), dtype=float64)
# iteration #:  8300
# tf.Tensor(46.164728945840594, shape=(), dtype=float64)
# tf.Tensor(124.2390960370061, shape=(), dtype=float64)
# iteration #:  8400
# tf.Tensor(46.15280082650911, shape=(), dtype=float64)
# tf.Tensor(124.24984960858595, shape=(), dtype=float64)
# iteration #:  8500
# tf.Tensor(46.13958457949486, shape=(), dtype=float64)
# tf.Tensor(124.26171566271353, shape=(), dtype=float64)
# iteration #:  8600
# tf.Tensor(46.15800195093684, shape=(), dtype=float64)
# tf.Tensor(124.24515784364615, shape=(), dtype=float64)
# iteration #:  8700
# tf.Tensor(46.16675260543748, shape=(), dtype=float64)
# tf.Tensor(124.23708231094577, shape=(), dtype=float64)
# iteration #:  8800
# tf.Tensor(46.146053847088965, shape=(), dtype=float64)
# tf.Tensor(124.25603736122628, shape=(), dtype=float64)
# iteration #:  8900
# tf.Tensor(46.13407863280777, shape=(), dtype=float64)
# tf.Tensor(124.27086630555726, shape=(), dtype=float64)
# iteration #:  9000
# tf.Tensor(46.15155928973525, shape=(), dtype=float64)
# tf.Tensor(124.25112806012734, shape=(), dtype=float64)
# iteration #:  9100
# tf.Tensor(46.16505057319303, shape=(), dtype=float64)
# tf.Tensor(124.23886109462295, shape=(), dtype=float64)
# iteration #:  9200
# tf.Tensor(46.16164641322971, shape=(), dtype=float64)
# tf.Tensor(124.24197141825523, shape=(), dtype=float64)
# iteration #:  9300
# tf.Tensor(46.128478534159925, shape=(), dtype=float64)
# tf.Tensor(124.2759250772724, shape=(), dtype=float64)
# iteration #:  9400
# tf.Tensor(46.1482697262792, shape=(), dtype=float64)
# tf.Tensor(124.25420015170177, shape=(), dtype=float64)
# iteration #:  9500
# tf.Tensor(46.163306979774234, shape=(), dtype=float64)
# tf.Tensor(124.24066625530601, shape=(), dtype=float64)
# iteration #:  9600
# tf.Tensor(46.15620564938014, shape=(), dtype=float64)
# tf.Tensor(124.24694515082214, shape=(), dtype=float64)
# iteration #:  9700
# tf.Tensor(46.12561544367076, shape=(), dtype=float64)
# tf.Tensor(124.27625409598406, shape=(), dtype=float64)
# iteration #:  9800
# tf.Tensor(46.14842313744896, shape=(), dtype=float64)
# tf.Tensor(124.25416209017882, shape=(), dtype=float64)
# iteration #:  9900
# tf.Tensor(46.16438631285195, shape=(), dtype=float64)
# tf.Tensor(124.23972315464924, shape=(), dtype=float64)

# %%
# %matplotlib inline
#keep the popup window from being a thing.

# %%
# plotting loss curves
plt.figure()
s_line, = plt.plot(sphere_terms,'r')
r_line, = plt.plot(repel_terms,'b')
p_line, = plt.plot(point_terms,'k')
plt.xlabel('# iterations')
plt.ylabel('loss function(s)')
plt.grid()
plt.legend((s_line,r_line, p_line),('sphere term','repel term', 'point term'))
plt.show()

# %%
tf_array = tf_pts.numpy()#gotta convert it to be useable. tf_pts is a special tensorflow variable.
print("the data type of tf_array is: " + str(type(tf_array)))
print("")

print("tf_array is:")
print(tf_array)
print("")

# check if distance of pts from origin is 1
print("the norm is....." + str(np.linalg.norm(tf_array,axis = 1)))
# Out:
# the data type of tf_array is: <class 'numpy.ndarray'>
#
# tf_array is:
# [[ 0.64128741 -0.46641012 -0.61232562]
#  [-0.56749063 -0.67815532  0.46736826]
#  [ 0.51235759  0.53198943  0.67812382]
#  [-0.58524085  0.61456713 -0.53420863]]
#
# the norm is.....[1.00186357 1.00018666 1.00268388 1.00278536]

# %%
# 2-D Plotting with unit circle
if NUM_DIMS == 2:
    # 2-D Plotting
    fig, axs = plt.subplots(1,1)
    axs.plot(tf_pts[:,0],tf_pts[:,1],'bs')
    axs.axis('equal')
    angles = np.linspace(0, 2 * np.pi, 100)
    axs.plot(np.cos(angles),np.sin(angles))

# %%
# 3-D Plotting with unit sphere
if NUM_DIMS == 3:
    a = tf_pts
    import matplotlib as mpl
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    xp = a[:,0]
    yp = a[:,1]
    zp = a[:,2]
    ax.plot(xp, yp, zp, 'bs')
    
    from mpl_toolkits.mplot3d import Axes3D
    import matplotlib.pyplot as plt
    import numpy as np


    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Make data
    u = np.linspace(0, 2 * np.pi, 100)
    v = np.linspace(0, np.pi, 100)
    x = np.outer(np.cos(u), np.sin(v))
    y = np.outer(np.sin(u), np.sin(v))
    z = np.outer(np.ones(np.size(u)), np.cos(v))

    # Plot the surface
    ax.plot_surface(x, y, z, color='b',alpha = 0.2)
    ax.scatter(xp, yp, zp, 'bs')

    plt.show()

# %% [markdown]
# I decided to just run the code 5 times rather than write a script to generate all of the shape arrays for me. It was more fun to mess around with settings than to lump all the shapes into a single batch. After running the optimization for a certain number of points, I would execute the relavent cell (below) and store those in a variable for use later. This did pose some problems, and if I had needed to do much more than 5 shapes I would have used a more elegant solution.

# %%
Tetrahedron = tf_pts.numpy()#4                              <---Done!

# %%
print(Tetrahedron)
# Out:
# [[-0.15002707  0.9897345   0.0191453 ]
#  [-0.86299958 -0.47290326  0.19082597]
#  [ 0.33579454 -0.26956161 -0.90503305]
#  [ 0.67780946 -0.24900342  0.69537813]]

# %%
Octahedron = tf_pts.numpy()#6                                <----Done!

# %%
print(Octahedron)
# Out:
# [[ 0.9484132   0.68935648 -0.53928403]
#  [ 0.83011862 -0.45879703  0.87327385]
#  [ 0.27500291 -0.98957959 -0.78125025]
#  [-0.82985657  0.458732   -0.87310991]
#  [-0.275004    0.98952974  0.78131717]
#  [-0.94838302 -0.68937455  0.53932475]]

# %%
Cube = tf_pts.numpy()#8                                     <----Done!

# %%
print(Cube)
# Out:
# [[ 0.73196542  0.40019974 -0.55550391]
#  [-0.54220502 -1.3491352   1.04216821]
#  [ 0.27562782  1.62288995  0.93463233]
#  [ 0.94937346 -1.30394469 -0.77329864]
#  [ 1.17140005 -0.24428879  1.09650134]
#  [-0.8348794   0.26377997  0.4864429 ]
#  [-1.01167943 -0.79041754 -0.99430889]
#  [-0.71810521  1.25605704 -1.22256144]]

# %%
Icosahedron = tf_pts.numpy()#12                           <---Done!

# %%
print(Icosahedron)
# Out:
# [[ 1.32228119  1.19121566  1.59132605]
#  [-0.79162647 -0.39272845 -2.31413701]
#  [-0.93253943  2.19745923  0.46845281]
#  [ 0.97421792 -0.22830035  0.01102249]
#  [-0.40222168  0.21409074  0.89139056]
#  [ 1.27908851 -1.52929515  1.42039555]
#  [ 1.62791354 -1.02027769 -1.56621652]
#  [ 1.33411127  1.6983452  -1.03822668]
#  [-2.30618267  0.013562   -0.24884126]
#  [-1.28963514 -1.10351336  1.8607043 ]
#  [-0.33028735  0.56455264 -0.75789311]
#  [-0.50556018 -1.80774707 -0.3613241 ]]

# %%
Dodecahedron = tf_ pts.numpy()#20                              <----Done!

# %%
print(Dodecahedron)
# Out:
# [[ 2.33037185 -1.58184319 -1.54094615]
#  [-2.82552738  0.62175067 -0.70108796]
#  [-0.21679405  0.9696667  -0.12025197]
#  [ 0.6813527   2.93430621 -0.92664707]
#  [ 1.27587437  0.27061482  2.65565874]
#  [ 2.78913472  1.47729095  0.50242165]
#  [-0.26238572 -3.07523097 -1.22368762]
#  [ 0.43728109  2.58383709  1.80202774]
#  [-1.84877965 -1.21258979 -2.41649754]
#  [ 1.96013031  0.93217361 -2.41605812]
#  [-1.15369764  0.43625527  1.90681537]
#  [ 0.2382942  -0.39002311 -1.54998386]
#  [-2.18114428  2.40589614  0.86215124]
#  [-1.0118989   1.5762224  -2.5583404 ]
#  [-0.80274196 -0.59601406  0.03559157]
#  [-2.70118704 -1.72081516  0.79103724]
#  [ 0.40186745 -2.05903789  0.76605695]
#  [ 2.69820387 -1.6655006   1.2361246 ]
#  [-0.67485902 -1.75218825  2.8783778 ]
#  [ 0.9688662  -0.05223496  0.24428765]]

# %%
#testing my slicing and striding skills
matrix = np.asarray([
    [1, 2, 4],
    [3, 4, 5],
    [3, 5, 3],
])

print(matrix[:,1])
# Out:
# [2 4 5]

# %%
#function that accepts an array of shapes to plot.
def plot_shapes(shapes):
    
    for shape in shapes:
    
        fig = plt.figure()
        ax = plt.axes(projection="3d")

        z_points = shape[:,2]
        x_points = shape[:,0]
        y_points = shape[:,1]
        ax.scatter3D(x_points, y_points, z_points, c=z_points, cmap='hsv');

        plt.show()
        
    
#put all our shapes in one array and plot 'em.
shape_array = [Tetrahedron, Octahedron, Cube, Icosahedron, Dodecahedron]
plot_shapes(shape_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1841b0c6911f> in <module>
#      16
#      17 #put all our shapes in one array and plot 'em.
# ---> 18 shape_array = [Tetrahedron, Octahedron, Cube, Icosahedron, Dodecahedron]
#      19 plot_shapes(shape_array)
#
# NameError: name 'Tetrahedron' is not defined

# %% [markdown]
# Side project: try and visualize my results well!

# %%
    
shape = Cube
fig = plt.figure()
ax = plt.axes(projection="3d")
z_points = shape[:,2]
x_points = shape[:,0]
y_points = shape[:,1]
ax.scatter3D(x_points, y_points, z_points, c=z_points, cmap='hsv');
plt.title = "hi"
plt.show()

#break Cube into x and y and z components in sets of 2 for points to connect.

class plot_container:
    def __init__():
    
    data = []
    
    def add_pair(point1, point2):
        if


#Take all the points that are distance V from each other, where V is the shortest distance between any pair of points in the set
def connect_the_dots(shape):
  
    fig = plt.figure()
    ax = plt.axes(projection="3d")
    
    for i in range(0, len(shape)):
        point1 = shape[i]
            
        for j in range(0, len(shape)):
            point2 = shape[j]
                
            if not plot_container.has_pair(point, point2):
                plot_container.add_pair(point1, point2)


connect_the_dots(Cube)#current error is that I don't get enough combinations of points.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-582c8085eda8> in <module>
#      27
#      28
# ---> 29 connect_the_dots(Cube)#current error is that I don't get enough combinations of points.
#      30
#      31
#
# <ipython-input-19-582c8085eda8> in connect_the_dots(shape)
#      23             point2 = shape[j]
#      24
# ---> 25             if not plot_container.has_pair(point, point2):
#      26                 plot_container.add_pair(point1, point2)
#      27
#
# NameError: name 'plot_container' is not defined

# %%
class point_pair_container:
    def __init__(self):  
        self.data = []
        
    def are_similar_arrays(self, arr1, arr2):
        #if arr1[1] == arr2[1] and arr1[0] == arr2[0]:
            return True
        
    def has_pair(self, point1, point2):
        for i in  range(0, len(data)):
            if self.are_similar_arrays(data[i], [point1, point2]):
                return True
            return False
        
    def add_pair(self, point1, point2):
        #if not self.has_pair(point1, point2) and not self.has_pair(point2, point1):
            self.data.append([point1, point2])
        
    def get_all_points(self):
        return self.data

# %%
from scipy.spatial import distance

def get_distance(point1, point2):
    return distance.euclidean(point1, point2)

def get_smallest_distance_with_tolerance(point_array, tolerance):
    smallest_distance = float("inf")
    
    for i in range(1, len(point_array)):#Don't count distance from 
        distance = get_distance(point_array[0], point_array[i])
        if distance < smallest_distance:
            smallest_distance = distance
    return [smallest_distance + tolerance, smallest_distance - tolerance]

# %%
def plot_points(Shape, tolerance):

    points_to_plot = point_pair_container()
    distance_array = get_smallest_distance_with_tolerance(Shape, tolerance)
    fig = plt.figure()
    ax = plt.axes(projection="3d")

    for i in range(0, len(Shape)):
        for j in range(0, len(Shape)):
            d = get_distance(Shape[i], Shape[j])
            
            if d < distance_array[0] and d > distance_array[1] and d is not 0:
                
                if not points_to_plot.has_pair(Shape[i], Shape[j]):
                    points_to_plot.add_pair(Shape[i], Shape[j])
    
    plot_these = points_to_plot.get_all_points()
    
    for i in range(0, len(plot_these)):
        pointA = plot_these[i][0]
        pointB = plot_these[i][1]
        
        ax.plot(pointA, pointB)

# %%
plot_points(Cube, 2.00001)
print(Cube)
# Out:
# [[ 0.73196542  0.40019974 -0.55550391]
#  [-0.54220502 -1.3491352   1.04216821]
#  [ 0.27562782  1.62288995  0.93463233]
#  [ 0.94937346 -1.30394469 -0.77329864]
#  [ 1.17140005 -0.24428879  1.09650134]
#  [-0.8348794   0.26377997  0.4864429 ]
#  [-1.01167943 -0.79041754 -0.99430889]
#  [-0.71810521  1.25605704 -1.22256144]]
