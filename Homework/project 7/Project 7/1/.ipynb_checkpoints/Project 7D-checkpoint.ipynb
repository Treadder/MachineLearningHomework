# %% [markdown]
# # Purpose and plan
#
# In this project, I will attempt to estimate the height of an individual based on their weight, gender, and BMI. I will implement Keras for the machine learning part of this assignment, and use Pandas and Matplotlib for data explotation. I know that the BMI of a person is calculated with height and weight, so I'm hoping that this model will ferrit out the relationship, (BMI = Kg/M^2,) and be able to accuractly predict height.

# %% [markdown]
# # Setup
#
# First, I'll import all needed libraries, and set things up so that this project should run smoothly on as many machines as possible. We also want to plot figures inline, so I'll use the built in Jupyter-Notebook magic for that.

# %%
# make sure we can support Python 2
from __future__ import division, print_function, unicode_literals

# import our necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
import keras
import os

# Plot figures in the notebook with Jupyter-Notebook magic
# %matplotlib inline

# give everything a random seed so that we get repeatable results.
seed_value= 42

os.environ['PYTHONHASHSEED']=str(seed_value)

import random
random.seed(seed_value)

np.random.seed(seed_value)

import tensorflow as tf
tf.random.set_seed(seed_value)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Time to import data from our CSV file! The file is named "HeightWeightData.csv," nd is stored in the same directory as this notebook.

# %%
# create paths for the loading of data, saving of models, and the saving of images.
DATA_PATH = "./HeightWeightData.csv"

if not os.path.exists("Figures"):
    os.makedirs("Figures")

if not os.path.exists("Models"):
    os.makedirs("Models")    
    
FIGURE_PATH = "./Figures/"

# %% [markdown]
# # Exploring and visualizing the data:
#
# Based on the online description of the dataset, the data should be structured as follows:
#
#     Gender : Male / Female
#
#     Height : Number (cm)
#
#     Weight : Number (Kg)
#
#     Index :
#
#         0 - Extremely Weak
#
#         1 - Weak
#
#         2 - Normal
#
#         3 - Overweight
#
#         4 - Obesity
#
#         5 - Extreme Obesity
#
# Now, just to make sure that there are no surprises, let's check out the data after importing it into a pandas DataFrame:

# %%
data = pd.read_csv(DATA_PATH)

data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# Gender    500 non-null object
# Height    500 non-null int64
# Weight    500 non-null int64
# Index     500 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %% [markdown]
# There is a single categorical data column to deal with. Let's explore what it contains, and in what amounts:

# %%
print(data["Gender"].value_counts())
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %% [markdown]
# Now we'll get some more information on how non-categorical features are spread out with the handy pandas hist() method.

# %%
data.hist(bins=50, figsize = [15, 15])
plt.show()

# %% [markdown]
# Because the hist() mehtod ignores categorical data, I'll just grab the value_counts of each variable in the "Gender" column, and plot those so that we have all variables visualized.

# %%
data["Gender"].value_counts().plot(kind="bar")#can't hist() on categorical.
plt.show()

# %% [markdown]
# What I've noticed so far is:
#
# 1) The data has buit in ratios. There are more females than males in the data, and there are a lot more people in the BMI "5" range than the other ranges. This will require some stratified splitting later if we want to avoid random sampling bias in the training/test sets.
#
# 2) There appears to be an obvious relationship between weight and height. I think the reason that the histogram for height and the histogram for weight are jumpy is the fact that there are only 500 instances in this set. I'm definately seeing parallels between the amount of people in a certain range of height, and the amount of people in a certain range of weight. If there were more instances, I think we'd see a much smoother top to the graph. (That smoothness doesn't have to be a straight line, of course.)
#
# I'll continue with a scatter matrix and correlation matrix:

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(data, figsize=[15,8])
plt.show()

print("")
corr_matrix = data.corr()
print(corr_matrix)
# Out:
#           Height    Weight     Index
# Height  1.000000  0.000446 -0.422223
# Weight  0.000446  1.000000  0.804569
# Index  -0.422223  0.804569  1.000000

# %% [markdown]
# Well after the scatter matrix and correlation matrix, I can tell that my previous assumptions about height and weight were incorrect. The relationship between height and weight is pretty much nothing. However, because BMI links the two with an equation, I am hoping that I can get my model to discover that relationship, and reverse-engineer it, so that it can accurately predict height. I'm hoping that I don't have to add another feature like (Weight/Height) to give the model any hints.

# %% [markdown]
# # Process the data for machine learning:
# As I mentioned previousely, we will need to be carefule when splitting up the data. I need the test/train matrices of features, (Index, Gender, and Weight,) and labels, (Height.) I also need to come up with a way to deal with the categorical data. This means that the first order of business is to throw the "Gender" column into a one-hot encoder in order to avoid the problems of false correlation that an ordinal encoder would cause.

# %%
temp_genders = pd.get_dummies(data["Gender"], prefix="Gender")
data = data.drop(["Gender"], axis=1)
data["Gender_Male"] = temp_genders["Gender_Male"]
data["Gender_Female"] = temp_genders["Gender_Female"]

# %% [markdown]
# I'll be doing stratified splitting of the data based around the "Index" feature, because it has the most variance, and I think it will have more effect than something like "Gender" in which the spread is fairly even. The docs for scikit-learn say that the y parameter in the StratifiedShuffleSplit method is supposed to be the target variable in the data, so I guess this is a bit of an experiment.

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=42) 
for train_index, test_index in split.split(data, data["Index"]):
    train_set = data.loc[train_index]
    test_set = data.loc[test_index]
    
split2 = StratifiedShuffleSplit(n_splits=1, test_size=0.11, random_state=42) 
for train_index, valid_index in split2.split(train_set, train_set["Index"]):
    train_set = data.loc[train_index]
    valid_set = data.loc[valid_index]

# %% [markdown]
# Now that I've split the data up, I'd like to make sure that everything worked out. I'll make a get_dataframe_info() method to check out the shape and 'head' of a data subset, and I'll create some histograms to compare the 'Index' columns' spread between the different data sets.

# %%
def get_dataframe_info(dframe, name):
    print("---------------------------------")
    print(name)
    print("")
    print("shape: " + str(np.shape(dframe)))
    print("")
    print(dframe.head())
    print("")

# %%
def get_array_info(array, name):
    print("------------------------")
    print(name + ":")
    print("")
    print("shape : " + str(np.shape(array)))
    print("")
    print("first 5 rows:")
    print(array[:5])
    print("")

# %%
#make sure everything went smoothly with the splitting:    
get_dataframe_info(train_set, "train_set")
get_dataframe_info(test_set, "test_set")
get_dataframe_info(valid_set, "valid_set")
# Out:
# ---------------------------------
# train_set
#
# shape: (400, 5)
#
#      Height  Weight  Index  Gender_Male  Gender_Female
# 147     140     146      5            0              1
# 377     178     142      5            1              0
# 105     195     126      4            1              0
# 7       154     111      5            1              0
# 179     188     100      3            1              0
#
# ---------------------------------
# test_set
#
# shape: (50, 5)
#
#      Height  Weight  Index  Gender_Male  Gender_Female
# 201     179      93      3            1              0
# 383     151     154      5            1              0
# 382     177     117      4            1              0
# 159     181     105      4            1              0
# 390     167      58      2            0              1
#
# ---------------------------------
# valid_set
#
# shape: (50, 5)
#
#      Height  Weight  Index  Gender_Male  Gender_Female
# 449     159     145      5            1              0
# 155     179     103      4            0              1
# 233     177      81      3            0              1
# 276     179     114      4            0              1
# 394     152     154      5            0              1

# %%
fig = plt.figure(figsize=(20, 6))

dataIndex = fig.add_subplot(1, 4, 1)
data["Index"].hist(bins=20)
dataIndex.title.set_text("Data['Index']")

testIndex = fig.add_subplot(1, 4, 2)
test_set["Index"].hist(bins=20)
testIndex.title.set_text("test_set['Index']")


trainIndex = fig.add_subplot(1, 4, 3)
train_set["Index"].hist(bins=20)
trainIndex.title.set_text("train_set['Index']")

validIndex = fig.add_subplot(1, 4, 4)
valid_set["Index"].hist(bins=20)
validIndex.title.set_text("valid_set['Index']")

plt.show()

# %% [markdown]
# We now have a test_set, valid_set, and train_set. I'm content with how those "Index" feature distributions turned out, so I'll move on to creating the label/feature subsets.

# %%
train_features = train_set[["Weight", "Gender_Male", "Gender_Female", "Index"]]
train_labels = train_set[["Height"]]

test_features = test_set[["Weight", "Gender_Male", "Gender_Female", "Index"]]
test_labels = test_set[["Height"]]

valid_features = valid_set[["Weight", "Gender_Male", "Gender_Female", "Index"]]
valid_labels = valid_set[["Height"]]

# %% [markdown]
# After several attempts at using the default features provided with this dataset, I have decided to change the "Index" column in all of the subsets. Becasue "Index" falls into one of five different categories, there is not enough information given to the model, and I am unable to get my loss lower than around 70. I'll turn all "Index" columns into an actual BMI measurement, which is calculated as: BMI = (Weight in Kilograms)/(Height in Meters squared)

# %%
def fix_index_column(dframe):
    dframe["Index"] = dframe["Weight"]/(dframe["Height"]/100)**2

fix_index_column(train_set)
fix_index_column(test_set)
fix_index_column(valid_set)

print(train_set.head())
print("")
print(train_set.corr())
# Out:
#      Height  Weight      Index  Gender_Male  Gender_Female
# 147     140     146  74.489796            0              1
# 377     178     142  44.817574            1              0
# 105     195     126  33.136095            1              0
# 7       154     111  46.803846            1              0
# 179     188     100  28.293345            1              0
#
#                  Height    Weight     Index  Gender_Male  Gender_Female
# Height         1.000000  0.000080 -0.529824    -0.010733       0.010733
# Weight         0.000080  1.000000  0.828242     0.000309      -0.000309
# Index         -0.529824  0.828242  1.000000     0.018109      -0.018109
# Gender_Male   -0.010733  0.000309  0.018109     1.000000      -1.000000
# Gender_Female  0.010733 -0.000309 -0.018109    -1.000000       1.000000

# %%
#optional: get some info on the sets.
get_dataframe_info(train_features, "train_features")
get_dataframe_info(train_labels, "train_labels")
get_dataframe_info(test_features, "test_features")
get_dataframe_info(test_labels, "test_labels")
get_dataframe_info(valid_features, "valid_features")
get_dataframe_info(valid_labels, "valid_labels")
# Out:
# ---------------------------------
# train_features
#
# shape: (400, 4)
#
#      Weight  Gender_Male  Gender_Female  Index
# 147     146            0              1      5
# 377     142            1              0      5
# 105     126            1              0      4
# 7       111            1              0      5
# 179     100            1              0      3
#
# ---------------------------------
# train_labels
#
# shape: (400, 1)
#
#      Height
# 147     140
# 377     178
# 105     195
# 7       154
# 179     188
#
# ---------------------------------
# test_features
#
# shape: (50, 4)
#
#      Weight  Gender_Male  Gender_Female  Index
# 201      93            1              0      3
# 383     154            1              0      5
# 382     117            1              0      4
# 159     105            1              0      4
# 390      58            0              1      2
#
# ---------------------------------
# test_labels
#
# shape: (50, 1)
#
#      Height
# 201     179
# 383     151
# 382     177
# 159     181
# 390     167
#
# ---------------------------------
# valid_features
#
# shape: (50, 4)
#
#      Weight  Gender_Male  Gender_Female  Index
# 449     145            1              0      5
# 155     103            0              1      4
# 233      81            0              1      3
# 276     114            0              1      4
# 394     154            0              1      5
#
# ---------------------------------
# valid_labels
#
# shape: (50, 1)
#
#      Height
# 449     159
# 155     179
# 233     177
# 276     179
# 394     152

# %% [markdown]
# As a final step before creating the neural network, I'll use a MinMaxScalar to rescale the data into a range between 0 and 1. I'm not worried about outliers, because there don't appear to be any. I decided not to scale my labels, because I found some material saying that this is not nescissary. Note: the MinMaxScaler outputs ndarray objects instead of the origional dataframes, so I'll convert all label sets to ndarrays as well.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

train_features = scaler.fit_transform(train_features)
test_features = scaler.fit_transform(test_features)
valid_features = scaler.fit_transform(valid_features)

train_labels = train_labels.to_numpy()
test_labels = test_labels.to_numpy()
valid_labels = valid_labels.to_numpy()

#train_labels = scaler.fit_transform(train_labels)
#test_labels = scaler.fit_transform(test_labels)
#valid_labels = scaler.fit_transform(valid_labels)

# %%
get_array_info(train_features, "train_features")
get_array_info(train_labels, "train_labels")
# Out:
# ------------------------
# train_features:
#
# shape : (400, 4)
#
# first 5 rows:
# [[0.87272727 0.         1.         1.        ]
#  [0.83636364 1.         0.         1.        ]
#  [0.69090909 1.         0.         0.8       ]
#  [0.55454545 1.         0.         1.        ]
#  [0.45454545 1.         0.         0.6       ]]
#
# ------------------------
# train_labels:
#
# shape : (400, 1)
#
# first 5 rows:
# [[140]
#  [178]
#  [195]
#  [154]
#  [188]]

# %% [markdown]
# # Prepare the machine learning algorithm
#
# Now that the data is ready for machine learning, I will use Keras to create a feedforward neural network with densly connected layers.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

keras.backend.clear_session()
model = Sequential()

model.add(Dense(10, activation="relu", input_shape=[4,]))
model.add(Dense(20, activation="relu"))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                50
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 291
# Trainable params: 291
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# I'll use Mean Squared Error as the loss for this, and also use it for metrics, because this is a regression problem.

# %%
model.compile(
 optimizer = tf.keras.optimizers.Adam(learning_rate=0.1),
 loss = "mean_squared_error",
 metrics = ["mean_squared_error"]
)

# %% [markdown]
# Time to train the model! I'll be using a callback that saves only the best model during this.

# %%
save_cb = keras.callbacks.ModelCheckpoint("./Models/proj_7_best_model.h5", save_best_only=True)

results = model.fit(
 train_features, train_labels,
 epochs= 2000,
 batch_size = 40,
 validation_data = (valid_features, valid_labels),
 callbacks=[save_cb]
)
# Out:
# Train on 400 samples, validate on 50 samples
# Epoch 1/2000
# 400/400 [==============================] - 0s 175us/step - loss: 18045.6358 - mean_squared_error: 18045.6367 - val_loss: 5025.0330 - val_mean_squared_error: 5025.0332
# Epoch 2/2000
# 400/400 [==============================] - 0s 26us/step - loss: 3427.5396 - mean_squared_error: 3427.5400 - val_loss: 2617.2216 - val_mean_squared_error: 2617.2217
# Epoch 3/2000
# 400/400 [==============================] - 0s 27us/step - loss: 1746.2769 - mean_squared_error: 1746.2767 - val_loss: 1099.3812 - val_mean_squared_error: 1099.3812
# Epoch 4/2000
# 400/400 [==============================] - 0s 25us/step - loss: 875.1981 - mean_squared_error: 875.1981 - val_loss: 579.2494 - val_mean_squared_error: 579.2494
# Epoch 5/2000
# 400/400 [==============================] - 0s 27us/step - loss: 598.1408 - mean_squared_error: 598.1408 - val_loss: 450.7699 - val_mean_squared_error: 450.7699
# Epoch 6/2000
# 400/400 [==============================] - 0s 30us/step - loss: 454.6245 - mean_squared_error: 454.6245 - val_loss: 365.9050 - val_mean_squared_error: 365.9050
# Epoch 7/2000
# 400/400 [==============================] - 0s 25us/step - loss: 376.5342 - mean_squared_error: 376.5342 - val_loss: 436.9327 - val_mean_squared_error: 436.9327
# Epoch 8/2000
# 400/400 [==============================] - 0s 27us/step - loss: 338.7931 - mean_squared_error: 338.7931 - val_loss: 274.9166 - val_mean_squared_error: 274.9165
# Epoch 9/2000
#  40/400 [==>...........................] - ETA: 0s - loss: 261.1801 - mean_squared_error: 261.1801
# C:\Anaconda\lib\site-packages\keras\engine\saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# 400/400 [==============================] - 0s 25us/step - loss: 281.3472 - mean_squared_error: 281.3472 - val_loss: 280.9714 - val_mean_squared_error: 280.9714
# Epoch 10/2000
# 400/400 [==============================] - 0s 27us/step - loss: 281.6397 - mean_squared_error: 281.6397 - val_loss: 253.4676 - val_mean_squared_error: 253.4676
# Epoch 11/2000
# 400/400 [==============================] - 0s 30us/step - loss: 242.5824 - mean_squared_error: 242.5824 - val_loss: 294.6693 - val_mean_squared_error: 294.6693
# Epoch 12/2000
# 400/400 [==============================] - 0s 30us/step - loss: 227.5016 - mean_squared_error: 227.5016 - val_loss: 275.6264 - val_mean_squared_error: 275.6264
# Epoch 13/2000
# 400/400 [==============================] - 0s 22us/step - loss: 213.5746 - mean_squared_error: 213.5746 - val_loss: 244.9881 - val_mean_squared_error: 244.9881
# Epoch 14/2000
# 400/400 [==============================] - 0s 27us/step - loss: 190.5028 - mean_squared_error: 190.5028 - val_loss: 202.0161 - val_mean_squared_error: 202.0161
# Epoch 15/2000
# 400/400 [==============================] - 0s 25us/step - loss: 185.0030 - mean_squared_error: 185.0030 - val_loss: 185.4680 - val_mean_squared_error: 185.4680
# Epoch 16/2000
# 400/400 [==============================] - 0s 25us/step - loss: 171.4764 - mean_squared_error: 171.4764 - val_loss: 183.2166 - val_mean_squared_error: 183.2166
# Epoch 17/2000
# 400/400 [==============================] - 0s 27us/step - loss: 163.2502 - mean_squared_error: 163.2502 - val_loss: 178.7260 - val_mean_squared_error: 178.7260
# Epoch 18/2000
# 400/400 [==============================] - 0s 25us/step - loss: 156.3753 - mean_squared_error: 156.3753 - val_loss: 170.9590 - val_mean_squared_error: 170.9589
# Epoch 19/2000
# 400/400 [==============================] - 0s 27us/step - loss: 155.4402 - mean_squared_error: 155.4402 - val_loss: 171.8683 - val_mean_squared_error: 171.8683
# Epoch 20/2000
# 400/400 [==============================] - 0s 27us/step - loss: 153.4387 - mean_squared_error: 153.4387 - val_loss: 163.4398 - val_mean_squared_error: 163.4398
# Epoch 21/2000
# 400/400 [==============================] - 0s 25us/step - loss: 145.7929 - mean_squared_error: 145.7929 - val_loss: 184.4491 - val_mean_squared_error: 184.4491
# Epoch 22/2000
# 400/400 [==============================] - 0s 27us/step - loss: 136.4798 - mean_squared_error: 136.4798 - val_loss: 169.0623 - val_mean_squared_error: 169.0623
# Epoch 23/2000
# 400/400 [==============================] - 0s 27us/step - loss: 135.2398 - mean_squared_error: 135.2398 - val_loss: 190.1587 - val_mean_squared_error: 190.1586
# Epoch 24/2000
# 400/400 [==============================] - 0s 27us/step - loss: 133.4553 - mean_squared_error: 133.4553 - val_loss: 153.3019 - val_mean_squared_error: 153.3019
# Epoch 25/2000
# 400/400 [==============================] - 0s 27us/step - loss: 134.1298 - mean_squared_error: 134.1298 - val_loss: 170.7302 - val_mean_squared_error: 170.7302
# Epoch 26/2000
# 400/400 [==============================] - 0s 30us/step - loss: 134.1049 - mean_squared_error: 134.1049 - val_loss: 166.1430 - val_mean_squared_error: 166.1429
# Epoch 27/2000
# 400/400 [==============================] - 0s 27us/step - loss: 135.6675 - mean_squared_error: 135.6675 - val_loss: 162.1528 - val_mean_squared_error: 162.1527
# Epoch 28/2000
# 400/400 [==============================] - 0s 27us/step - loss: 132.8135 - mean_squared_error: 132.8135 - val_loss: 171.4027 - val_mean_squared_error: 171.4027
# Epoch 29/2000
# 400/400 [==============================] - 0s 27us/step - loss: 130.3666 - mean_squared_error: 130.3666 - val_loss: 208.6509 - val_mean_squared_error: 208.6509
# Epoch 30/2000
# 400/400 [==============================] - 0s 27us/step - loss: 134.9963 - mean_squared_error: 134.9963 - val_loss: 167.6326 - val_mean_squared_error: 167.6326
# Epoch 31/2000
# 400/400 [==============================] - 0s 25us/step - loss: 140.9394 - mean_squared_error: 140.9394 - val_loss: 190.2259 - val_mean_squared_error: 190.2259
# Epoch 32/2000
# 400/400 [==============================] - 0s 27us/step - loss: 132.2315 - mean_squared_error: 132.2315 - val_loss: 170.2627 - val_mean_squared_error: 170.2627
# Epoch 33/2000
# 400/400 [==============================] - 0s 22us/step - loss: 142.0200 - mean_squared_error: 142.0201 - val_loss: 261.4243 - val_mean_squared_error: 261.4243
# Epoch 34/2000
# 400/400 [==============================] - 0s 25us/step - loss: 145.1391 - mean_squared_error: 145.1391 - val_loss: 223.7402 - val_mean_squared_error: 223.7402
# Epoch 35/2000
# 400/400 [==============================] - 0s 27us/step - loss: 142.4027 - mean_squared_error: 142.4027 - val_loss: 198.3645 - val_mean_squared_error: 198.3645
# Epoch 36/2000
# 400/400 [==============================] - 0s 25us/step - loss: 138.2099 - mean_squared_error: 138.2099 - val_loss: 153.6381 - val_mean_squared_error: 153.6381
# Epoch 37/2000
# 400/400 [==============================] - 0s 27us/step - loss: 136.2486 - mean_squared_error: 136.2486 - val_loss: 175.0262 - val_mean_squared_error: 175.0262
# Epoch 38/2000
# 400/400 [==============================] - 0s 27us/step - loss: 142.1271 - mean_squared_error: 142.1272 - val_loss: 159.8981 - val_mean_squared_error: 159.8981
# Epoch 39/2000
# 400/400 [==============================] - 0s 25us/step - loss: 140.3799 - mean_squared_error: 140.3799 - val_loss: 178.9308 - val_mean_squared_error: 178.9308
# Epoch 40/2000
# 400/400 [==============================] - 0s 25us/step - loss: 139.6122 - mean_squared_error: 139.6121 - val_loss: 174.8314 - val_mean_squared_error: 174.8314
# Epoch 41/2000
# 400/400 [==============================] - 0s 25us/step - loss: 142.1082 - mean_squared_error: 142.1082 - val_loss: 164.3491 - val_mean_squared_error: 164.3491
# Epoch 42/2000
# 400/400 [==============================] - 0s 27us/step - loss: 139.3955 - mean_squared_error: 139.3955 - val_loss: 158.6207 - val_mean_squared_error: 158.6207
# Epoch 43/2000
# 400/400 [==============================] - 0s 32us/step - loss: 140.6494 - mean_squared_error: 140.6494 - val_loss: 175.4174 - val_mean_squared_error: 175.4174
# Epoch 44/2000
# 400/400 [==============================] - 0s 30us/step - loss: 138.4373 - mean_squared_error: 138.4373 - val_loss: 220.1641 - val_mean_squared_error: 220.1641
# Epoch 45/2000
# 400/400 [==============================] - 0s 30us/step - loss: 136.2849 - mean_squared_error: 136.2849 - val_loss: 166.3784 - val_mean_squared_error: 166.3785
# Epoch 46/2000
# 400/400 [==============================] - 0s 25us/step - loss: 132.8745 - mean_squared_error: 132.8745 - val_loss: 202.0571 - val_mean_squared_error: 202.0571
# Epoch 47/2000
# 400/400 [==============================] - 0s 27us/step - loss: 131.9571 - mean_squared_error: 131.9571 - val_loss: 169.4462 - val_mean_squared_error: 169.4462
# Epoch 48/2000
# 400/400 [==============================] - 0s 27us/step - loss: 145.7404 - mean_squared_error: 145.7404 - val_loss: 161.2387 - val_mean_squared_error: 161.2387
# Epoch 49/2000
# 400/400 [==============================] - 0s 25us/step - loss: 140.2032 - mean_squared_error: 140.2031 - val_loss: 204.0394 - val_mean_squared_error: 204.0394
# Epoch 50/2000
# 400/400 [==============================] - 0s 25us/step - loss: 139.6330 - mean_squared_error: 139.6330 - val_loss: 202.5105 - val_mean_squared_error: 202.5105
# Epoch 51/2000
# 400/400 [==============================] - 0s 27us/step - loss: 134.9448 - mean_squared_error: 134.9448 - val_loss: 180.1970 - val_mean_squared_error: 180.1970
# Epoch 52/2000
# 400/400 [==============================] - 0s 77us/step - loss: 138.7699 - mean_squared_error: 138.7699 - val_loss: 172.1426 - val_mean_squared_error: 172.1426
# Epoch 53/2000
# 400/400 [==============================] - 0s 27us/step - loss: 135.1339 - mean_squared_error: 135.1339 - val_loss: 213.6049 - val_mean_squared_error: 213.6049
# Epoch 54/2000
# 400/400 [==============================] - 0s 35us/step - loss: 144.7765 - mean_squared_error: 144.7765 - val_loss: 245.9285 - val_mean_squared_error: 245.9285
# Epoch 55/2000
# 400/400 [==============================] - 0s 42us/step - loss: 154.4969 - mean_squared_error: 154.4969 - val_loss: 164.1500 - val_mean_squared_error: 164.1500
# Epoch 56/2000
# 400/400 [==============================] - 0s 57us/step - loss: 146.6954 - mean_squared_error: 146.6954 - val_loss: 221.8539 - val_mean_squared_error: 221.8539
# Epoch 57/2000
# 400/400 [==============================] - 0s 32us/step - loss: 140.8123 - mean_squared_error: 140.8123 - val_loss: 188.5786 - val_mean_squared_error: 188.5786
# Epoch 58/2000
# 400/400 [==============================] - 0s 40us/step - loss: 137.4501 - mean_squared_error: 137.4501 - val_loss: 165.1377 - val_mean_squared_error: 165.1377
# Epoch 59/2000
# 400/400 [==============================] - 0s 35us/step - loss: 147.6583 - mean_squared_error: 147.6583 - val_loss: 253.8743 - val_mean_squared_error: 253.8743
# Epoch 60/2000
# 400/400 [==============================] - 0s 45us/step - loss: 138.4003 - mean_squared_error: 138.4003 - val_loss: 264.6229 - val_mean_squared_error: 264.6229
# Epoch 61/2000
# 400/400 [==============================] - 0s 62us/step - loss: 152.6573 - mean_squared_error: 152.6573 - val_loss: 150.4722 - val_mean_squared_error: 150.4722
# Epoch 62/2000
# 400/400 [==============================] - 0s 47us/step - loss: 166.3038 - mean_squared_error: 166.3038 - val_loss: 173.0042 - val_mean_squared_error: 173.0042
# Epoch 63/2000
# 400/400 [==============================] - 0s 77us/step - loss: 145.8122 - mean_squared_error: 145.8122 - val_loss: 202.5887 - val_mean_squared_error: 202.5887
# Epoch 64/2000
# 400/400 [==============================] - 0s 32us/step - loss: 138.6458 - mean_squared_error: 138.6458 - val_loss: 172.9428 - val_mean_squared_error: 172.9427
# Epoch 65/2000
# 400/400 [==============================] - 0s 37us/step - loss: 138.6607 - mean_squared_error: 138.6607 - val_loss: 209.6749 - val_mean_squared_error: 209.6749
# Epoch 66/2000
# 400/400 [==============================] - 0s 69us/step - loss: 154.1123 - mean_squared_error: 154.1123 - val_loss: 167.0575 - val_mean_squared_error: 167.0575
# Epoch 67/2000
# 400/400 [==============================] - 0s 50us/step - loss: 138.9298 - mean_squared_error: 138.9297 - val_loss: 162.7785 - val_mean_squared_error: 162.7785
# Epoch 68/2000
# 400/400 [==============================] - 0s 50us/step - loss: 137.8596 - mean_squared_error: 137.8596 - val_loss: 198.6503 - val_mean_squared_error: 198.6503
# Epoch 69/2000
# 400/400 [==============================] - 0s 30us/step - loss: 133.8345 - mean_squared_error: 133.8345 - val_loss: 151.7458 - val_mean_squared_error: 151.7458
# Epoch 70/2000
# 400/400 [==============================] - 0s 32us/step - loss: 165.2963 - mean_squared_error: 165.2963 - val_loss: 199.0000 - val_mean_squared_error: 199.0000
# Epoch 71/2000
# 400/400 [==============================] - 0s 47us/step - loss: 142.5960 - mean_squared_error: 142.5960 - val_loss: 165.6846 - val_mean_squared_error: 165.6846
# Epoch 72/2000
# 400/400 [==============================] - 0s 42us/step - loss: 141.3178 - mean_squared_error: 141.3178 - val_loss: 189.6505 - val_mean_squared_error: 189.6505
# Epoch 73/2000
# 400/400 [==============================] - 0s 30us/step - loss: 130.9743 - mean_squared_error: 130.9743 - val_loss: 156.0502 - val_mean_squared_error: 156.0502
# Epoch 74/2000
# 400/400 [==============================] - 0s 30us/step - loss: 135.3357 - mean_squared_error: 135.3357 - val_loss: 208.9051 - val_mean_squared_error: 208.9051
# Epoch 75/2000
# 400/400 [==============================] - 0s 37us/step - loss: 134.0240 - mean_squared_error: 134.0240 - val_loss: 163.9945 - val_mean_squared_error: 163.9945
# Epoch 76/2000
# 400/400 [==============================] - 0s 27us/step - loss: 131.5904 - mean_squared_error: 131.5904 - val_loss: 183.4520 - val_mean_squared_error: 183.4520
# Epoch 77/2000
# 400/400 [==============================] - 0s 27us/step - loss: 134.2976 - mean_squared_error: 134.2976 - val_loss: 171.9196 - val_mean_squared_error: 171.9196
# Epoch 78/2000
# 400/400 [==============================] - 0s 25us/step - loss: 132.4603 - mean_squared_error: 132.4603 - val_loss: 209.1818 - val_mean_squared_error: 209.1818
# Epoch 79/2000
# 400/400 [==============================] - 0s 25us/step - loss: 132.7968 - mean_squared_error: 132.7968 - val_loss: 162.5813 - val_mean_squared_error: 162.5813
# Epoch 80/2000
# 400/400 [==============================] - 0s 29us/step - loss: 148.7180 - mean_squared_error: 148.7180 - val_loss: 197.2521 - val_mean_squared_error: 197.2521
# Epoch 81/2000
# 400/400 [==============================] - 0s 26us/step - loss: 135.1387 - mean_squared_error: 135.1387 - val_loss: 171.2195 - val_mean_squared_error: 171.2195
# Epoch 82/2000
# 400/400 [==============================] - 0s 22us/step - loss: 142.1658 - mean_squared_error: 142.1658 - val_loss: 220.9868 - val_mean_squared_error: 220.9868
# Epoch 83/2000
# 400/400 [==============================] - 0s 25us/step - loss: 134.2450 - mean_squared_error: 134.2450 - val_loss: 222.7474 - val_mean_squared_error: 222.7474
# Epoch 84/2000
# 400/400 [==============================] - 0s 34us/step - loss: 152.2699 - mean_squared_error: 152.2699 - val_loss: 161.8590 - val_mean_squared_error: 161.8590
# Epoch 85/2000
# 400/400 [==============================] - 0s 29us/step - loss: 159.1186 - mean_squared_error: 159.1186 - val_loss: 215.5223 - val_mean_squared_error: 215.5223
# Epoch 86/2000
# 400/400 [==============================] - 0s 28us/step - loss: 155.2409 - mean_squared_error: 155.2409 - val_loss: 159.8227 - val_mean_squared_error: 159.8227
# Epoch 87/2000
# 400/400 [==============================] - 0s 25us/step - loss: 142.2931 - mean_squared_error: 142.2931 - val_loss: 212.8520 - val_mean_squared_error: 212.8520
# Epoch 88/2000
# 400/400 [==============================] - 0s 27us/step - loss: 140.3053 - mean_squared_error: 140.3053 - val_loss: 278.8300 - val_mean_squared_error: 278.8300
# Epoch 89/2000
# 400/400 [==============================] - 0s 27us/step - loss: 142.9450 - mean_squared_error: 142.9450 - val_loss: 165.8492 - val_mean_squared_error: 165.8492
# Epoch 90/2000
# 400/400 [==============================] - 0s 27us/step - loss: 149.1309 - mean_squared_error: 149.1309 - val_loss: 209.4772 - val_mean_squared_error: 209.4772
# Epoch 91/2000
# 400/400 [==============================] - 0s 22us/step - loss: 193.5565 - mean_squared_error: 193.5565 - val_loss: 221.9788 - val_mean_squared_error: 221.9788
# Epoch 92/2000
# 400/400 [==============================] - 0s 28us/step - loss: 145.3320 - mean_squared_error: 145.3320 - val_loss: 168.7294 - val_mean_squared_error: 168.7294
# Epoch 93/2000
# 400/400 [==============================] - 0s 27us/step - loss: 134.1120 - mean_squared_error: 134.1120 - val_loss: 176.8003 - val_mean_squared_error: 176.8003
# Epoch 94/2000
# 400/400 [==============================] - 0s 22us/step - loss: 132.4220 - mean_squared_error: 132.4220 - val_loss: 213.5286 - val_mean_squared_error: 213.5287
# Epoch 95/2000
# 400/400 [==============================] - 0s 25us/step - loss: 135.5827 - mean_squared_error: 135.5827 - val_loss: 186.4959 - val_mean_squared_error: 186.4959
# Epoch 96/2000
# 400/400 [==============================] - 0s 28us/step - loss: 133.7658 - mean_squared_error: 133.7658 - val_loss: 172.1952 - val_mean_squared_error: 172.1952
# Epoch 97/2000
# 400/400 [==============================] - 0s 25us/step - loss: 138.8224 - mean_squared_error: 138.8224 - val_loss: 206.0921 - val_mean_squared_error: 206.0921
# Epoch 98/2000
# 400/400 [==============================] - 0s 25us/step - loss: 135.9752 - mean_squared_error: 135.9752 - val_loss: 173.6799 - val_mean_squared_error: 173.6799
# Epoch 99/2000
# 400/400 [==============================] - 0s 27us/step - loss: 138.7407 - mean_squared_error: 138.7407 - val_loss: 255.7091 - val_mean_squared_error: 255.7091
# Epoch 100/2000
# 400/400 [==============================] - 0s 27us/step - loss: 161.1384 - mean_squared_error: 161.1384 - val_loss: 165.9787 - val_mean_squared_error: 165.9787
# Epoch 101/2000
# 400/400 [==============================] - 0s 25us/step - loss: 133.2964 - mean_squared_error: 133.2964 - val_loss: 164.8001 - val_mean_squared_error: 164.8001
# Epoch 102/2000
# 400/400 [==============================] - 0s 22us/step - loss: 135.2804 - mean_squared_error: 135.2805 - val_loss: 175.8225 - val_mean_squared_error: 175.8225
# Epoch 103/2000
# 400/400 [==============================] - 0s 28us/step - loss: 133.1267 - mean_squared_error: 133.1267 - val_loss: 163.8419 - val_mean_squared_error: 163.8419
# Epoch 104/2000
# 400/400 [==============================] - 0s 40us/step - loss: 132.2537 - mean_squared_error: 132.2537 - val_loss: 217.5395 - val_mean_squared_error: 217.5396
# Epoch 105/2000
# 400/400 [==============================] - 0s 45us/step - loss: 138.6469 - mean_squared_error: 138.6469 - val_loss: 185.2730 - val_mean_squared_error: 185.2730
# Epoch 106/2000
# 400/400 [==============================] - 0s 25us/step - loss: 129.7214 - mean_squared_error: 129.7214 - val_loss: 208.2694 - val_mean_squared_error: 208.2694
# Epoch 107/2000
# 400/400 [==============================] - 0s 30us/step - loss: 143.4424 - mean_squared_error: 143.4424 - val_loss: 154.2408 - val_mean_squared_error: 154.2408
# Epoch 108/2000
# 400/400 [==============================] - 0s 29us/step - loss: 152.9832 - mean_squared_error: 152.9832 - val_loss: 258.0282 - val_mean_squared_error: 258.0282
# Epoch 109/2000
# 400/400 [==============================] - 0s 26us/step - loss: 141.9112 - mean_squared_error: 141.9112 - val_loss: 195.4880 - val_mean_squared_error: 195.4881
# Epoch 110/2000
# 400/400 [==============================] - 0s 25us/step - loss: 134.8461 - mean_squared_error: 134.8461 - val_loss: 188.6330 - val_mean_squared_error: 188.6330
# Epoch 111/2000
# 400/400 [==============================] - 0s 37us/step - loss: 133.2249 - mean_squared_error: 133.2249 - val_loss: 189.9596 - val_mean_squared_error: 189.9596
# Epoch 112/2000
# 400/400 [==============================] - 0s 32us/step - loss: 154.9082 - mean_squared_error: 154.9082 - val_loss: 153.6807 - val_mean_squared_error: 153.6808
# Epoch 113/2000
# 400/400 [==============================] - 0s 30us/step - loss: 177.8911 - mean_squared_error: 177.8911 - val_loss: 322.6586 - val_mean_squared_error: 322.6586
# Epoch 114/2000
# 400/400 [==============================] - 0s 27us/step - loss: 154.0329 - mean_squared_error: 154.0329 - val_loss: 194.4392 - val_mean_squared_error: 194.4392
# Epoch 115/2000
# 400/400 [==============================] - 0s 25us/step - loss: 131.8289 - mean_squared_error: 131.8289 - val_loss: 146.3422 - val_mean_squared_error: 146.3422
# Epoch 116/2000
# 400/400 [==============================] - 0s 27us/step - loss: 149.5425 - mean_squared_error: 149.5425 - val_loss: 245.7640 - val_mean_squared_error: 245.7640
# Epoch 117/2000
# 400/400 [==============================] - 0s 25us/step - loss: 139.8758 - mean_squared_error: 139.8758 - val_loss: 178.7472 - val_mean_squared_error: 178.7472
# Epoch 118/2000
# 400/400 [==============================] - 0s 25us/step - loss: 143.8298 - mean_squared_error: 143.8298 - val_loss: 279.1027 - val_mean_squared_error: 279.1027
# Epoch 119/2000
# 400/400 [==============================] - 0s 26us/step - loss: 138.5543 - mean_squared_error: 138.5543 - val_loss: 160.5772 - val_mean_squared_error: 160.5772
# Epoch 120/2000
# 400/400 [==============================] - 0s 25us/step - loss: 140.0930 - mean_squared_error: 140.0930 - val_loss: 258.6898 - val_mean_squared_error: 258.6898
# Epoch 121/2000
# 400/400 [==============================] - 0s 22us/step - loss: 145.0308 - mean_squared_error: 145.0308 - val_loss: 150.0031 - val_mean_squared_error: 150.0031
# Epoch 122/2000
# 400/400 [==============================] - 0s 35us/step - loss: 133.0265 - mean_squared_error: 133.0265 - val_loss: 229.0673 - val_mean_squared_error: 229.0673
# Epoch 123/2000
# 400/400 [==============================] - 0s 25us/step - loss: 135.2028 - mean_squared_error: 135.2028 - val_loss: 201.8303 - val_mean_squared_error: 201.8303
# Epoch 124/2000
# 400/400 [==============================] - 0s 27us/step - loss: 140.7547 - mean_squared_error: 140.7547 - val_loss: 182.5225 - val_mean_squared_error: 182.5225
# Epoch 125/2000
# 400/400 [==============================] - 0s 27us/step - loss: 166.5509 - mean_squared_error: 166.5509 - val_loss: 289.5134 - val_mean_squared_error: 289.5134
# Epoch 126/2000
# 400/400 [==============================] - 0s 30us/step - loss: 160.8029 - mean_squared_error: 160.8029 - val_loss: 176.1112 - val_mean_squared_error: 176.1112
# Epoch 127/2000
# 400/400 [==============================] - 0s 27us/step - loss: 154.4518 - mean_squared_error: 154.4518 - val_loss: 141.9183 - val_mean_squared_error: 141.9183
# Epoch 128/2000
# 400/400 [==============================] - 0s 25us/step - loss: 171.2318 - mean_squared_error: 171.2318 - val_loss: 252.9403 - val_mean_squared_error: 252.9403
# Epoch 129/2000
# 400/400 [==============================] - 0s 22us/step - loss: 149.6800 - mean_squared_error: 149.6801 - val_loss: 183.7061 - val_mean_squared_error: 183.7061
# Epoch 130/2000
# 400/400 [==============================] - 0s 25us/step - loss: 138.5100 - mean_squared_error: 138.5100 - val_loss: 196.8791 - val_mean_squared_error: 196.8791
# Epoch 131/2000
# 400/400 [==============================] - 0s 25us/step - loss: 128.8133 - mean_squared_error: 128.8133 - val_loss: 152.8190 - val_mean_squared_error: 152.8190
# Epoch 132/2000
# 400/400 [==============================] - 0s 22us/step - loss: 166.6670 - mean_squared_error: 166.6670 - val_loss: 166.3367 - val_mean_squared_error: 166.3367
# Epoch 133/2000
# 400/400 [==============================] - 0s 25us/step - loss: 171.7589 - mean_squared_error: 171.7589 - val_loss: 558.1932 - val_mean_squared_error: 558.1932
# Epoch 134/2000
# 400/400 [==============================] - 0s 30us/step - loss: 223.3168 - mean_squared_error: 223.3168 - val_loss: 197.1748 - val_mean_squared_error: 197.1748
# Epoch 135/2000
# 400/400 [==============================] - 0s 25us/step - loss: 189.7537 - mean_squared_error: 189.7536 - val_loss: 179.7119 - val_mean_squared_error: 179.7119
# Epoch 136/2000
# 400/400 [==============================] - 0s 22us/step - loss: 178.8601 - mean_squared_error: 178.8601 - val_loss: 315.8775 - val_mean_squared_error: 315.8775
# Epoch 137/2000
# 400/400 [==============================] - 0s 25us/step - loss: 159.8156 - mean_squared_error: 159.8156 - val_loss: 156.6467 - val_mean_squared_error: 156.6467
# Epoch 138/2000
# 400/400 [==============================] - 0s 25us/step - loss: 144.6852 - mean_squared_error: 144.6852 - val_loss: 188.5235 - val_mean_squared_error: 188.5236
# Epoch 139/2000
# 400/400 [==============================] - 0s 25us/step - loss: 139.2393 - mean_squared_error: 139.2393 - val_loss: 214.5525 - val_mean_squared_error: 214.5525
# Epoch 140/2000
# 400/400 [==============================] - 0s 25us/step - loss: 143.2589 - mean_squared_error: 143.2589 - val_loss: 159.5367 - val_mean_squared_error: 159.5367
# Epoch 141/2000
# 400/400 [==============================] - 0s 22us/step - loss: 136.4178 - mean_squared_error: 136.4178 - val_loss: 344.9143 - val_mean_squared_error: 344.9143
# Epoch 142/2000
# 400/400 [==============================] - 0s 22us/step - loss: 165.9003 - mean_squared_error: 165.9003 - val_loss: 174.1314 - val_mean_squared_error: 174.1314
# Epoch 143/2000
# 400/400 [==============================] - 0s 27us/step - loss: 139.3749 - mean_squared_error: 139.3749 - val_loss: 184.0856 - val_mean_squared_error: 184.0856
# Epoch 144/2000
# 400/400 [==============================] - 0s 25us/step - loss: 157.6510 - mean_squared_error: 157.6510 - val_loss: 358.4781 - val_mean_squared_error: 358.4781
# Epoch 145/2000
# 400/400 [==============================] - 0s 25us/step - loss: 184.0839 - mean_squared_error: 184.0839 - val_loss: 185.5195 - val_mean_squared_error: 185.5195
# Epoch 146/2000
# 400/400 [==============================] - 0s 22us/step - loss: 161.4883 - mean_squared_error: 161.4883 - val_loss: 370.7876 - val_mean_squared_error: 370.7876
# Epoch 147/2000
# 400/400 [==============================] - 0s 25us/step - loss: 149.2449 - mean_squared_error: 149.2449 - val_loss: 160.7054 - val_mean_squared_error: 160.7054
# Epoch 148/2000
# 400/400 [==============================] - 0s 22us/step - loss: 138.0561 - mean_squared_error: 138.0561 - val_loss: 172.0485 - val_mean_squared_error: 172.0485
# Epoch 149/2000
# 400/400 [==============================] - 0s 25us/step - loss: 151.6338 - mean_squared_error: 151.6339 - val_loss: 189.7127 - val_mean_squared_error: 189.7127
# Epoch 150/2000
# 400/400 [==============================] - 0s 27us/step - loss: 150.1728 - mean_squared_error: 150.1728 - val_loss: 154.5660 - val_mean_squared_error: 154.5660
# Epoch 151/2000
# 400/400 [==============================] - 0s 25us/step - loss: 155.6913 - mean_squared_error: 155.6913 - val_loss: 245.1640 - val_mean_squared_error: 245.1640
# Epoch 152/2000
# 400/400 [==============================] - 0s 22us/step - loss: 140.7908 - mean_squared_error: 140.7908 - val_loss: 155.8257 - val_mean_squared_error: 155.8257
# Epoch 153/2000
# 400/400 [==============================] - 0s 25us/step - loss: 140.4613 - mean_squared_error: 140.4613 - val_loss: 227.1288 - val_mean_squared_error: 227.1288
# Epoch 154/2000
# 400/400 [==============================] - 0s 22us/step - loss: 145.2022 - mean_squared_error: 145.2022 - val_loss: 198.4252 - val_mean_squared_error: 198.4252
# Epoch 155/2000
# 400/400 [==============================] - 0s 25us/step - loss: 135.7828 - mean_squared_error: 135.7828 - val_loss: 200.3118 - val_mean_squared_error: 200.3118
# Epoch 156/2000
# 400/400 [==============================] - 0s 22us/step - loss: 132.1045 - mean_squared_error: 132.1045 - val_loss: 172.9150 - val_mean_squared_error: 172.9150
# Epoch 157/2000
# 400/400 [==============================] - 0s 25us/step - loss: 132.5127 - mean_squared_error: 132.5127 - val_loss: 174.0075 - val_mean_squared_error: 174.0075
# Epoch 158/2000
# 400/400 [==============================] - 0s 25us/step - loss: 130.9852 - mean_squared_error: 130.9852 - val_loss: 171.5844 - val_mean_squared_error: 171.5844
# Epoch 159/2000
# 400/400 [==============================] - 0s 25us/step - loss: 135.6672 - mean_squared_error: 135.6672 - val_loss: 182.1718 - val_mean_squared_error: 182.1718
# Epoch 160/2000
# 400/400 [==============================] - 0s 25us/step - loss: 142.5296 - mean_squared_error: 142.5296 - val_loss: 163.8101 - val_mean_squared_error: 163.8101
# Epoch 161/2000
# 400/400 [==============================] - 0s 22us/step - loss: 157.9693 - mean_squared_error: 157.9694 - val_loss: 181.6732 - val_mean_squared_error: 181.6732
# Epoch 162/2000
# 400/400 [==============================] - ETA: 0s - loss: 138.8148 - mean_squared_error: 138.81 - 0s 22us/step - loss: 151.6120 - mean_squared_error: 151.6120 - val_loss: 205.8066 - val_mean_squared_error: 205.8066
# Epoch 163/2000
# 400/400 [==============================] - 0s 25us/step - loss: 138.7763 - mean_squared_error: 138.7763 - val_loss: 195.0283 - val_mean_squared_error: 195.0283
# Epoch 164/2000
# 400/400 [==============================] - 0s 22us/step - loss: 140.7915 - mean_squared_error: 140.7915 - val_loss: 159.6445 - val_mean_squared_error: 159.6445
# Epoch 165/2000
# 400/400 [==============================] - 0s 25us/step - loss: 136.9527 - mean_squared_error: 136.9527 - val_loss: 285.1278 - val_mean_squared_error: 285.1278
# Epoch 166/2000
# 400/400 [==============================] - 0s 25us/step - loss: 162.8347 - mean_squared_error: 162.8347 - val_loss: 144.9813 - val_mean_squared_error: 144.9813
# Epoch 167/2000
# 400/400 [==============================] - 0s 25us/step - loss: 159.6103 - mean_squared_error: 159.6103 - val_loss: 250.2070 - val_mean_squared_error: 250.2070
# Epoch 168/2000
# 400/400 [==============================] - 0s 22us/step - loss: 148.8565 - mean_squared_error: 148.8565 - val_loss: 158.1753 - val_mean_squared_error: 158.1752
# Epoch 169/2000
# 400/400 [==============================] - 0s 25us/step - loss: 139.3129 - mean_squared_error: 139.3129 - val_loss: 233.4859 - val_mean_squared_error: 233.4859
# Epoch 170/2000
# 400/400 [==============================] - 0s 22us/step - loss: 157.2771 - mean_squared_error: 157.2771 - val_loss: 157.6275 - val_mean_squared_error: 157.6275
# Epoch 171/2000
# 400/400 [==============================] - 0s 25us/step - loss: 170.0915 - mean_squared_error: 170.0915 - val_loss: 148.1488 - val_mean_squared_error: 148.1488
# Epoch 172/2000
# 400/400 [==============================] - 0s 27us/step - loss: 199.1045 - mean_squared_error: 199.1045 - val_loss: 527.7672 - val_mean_squared_error: 527.7672
# Epoch 173/2000
# 400/400 [==============================] - 0s 25us/step - loss: 213.6819 - mean_squared_error: 213.6819 - val_loss: 155.4254 - val_mean_squared_error: 155.4254
# Epoch 174/2000
# 400/400 [==============================] - 0s 25us/step - loss: 143.5407 - mean_squared_error: 143.5407 - val_loss: 223.5675 - val_mean_squared_error: 223.5675
# Epoch 175/2000
# 400/400 [==============================] - 0s 22us/step - loss: 133.6962 - mean_squared_error: 133.6962 - val_loss: 222.4276 - val_mean_squared_error: 222.4276
# Epoch 176/2000
# 400/400 [==============================] - 0s 25us/step - loss: 136.0363 - mean_squared_error: 136.0363 - val_loss: 168.2336 - val_mean_squared_error: 168.2336
# Epoch 177/2000
# 400/400 [==============================] - 0s 25us/step - loss: 149.5463 - mean_squared_error: 149.5463 - val_loss: 165.4921 - val_mean_squared_error: 165.4921
# Epoch 178/2000
# 400/400 [==============================] - 0s 22us/step - loss: 154.9700 - mean_squared_error: 154.9700 - val_loss: 471.4578 - val_mean_squared_error: 471.4578
# Epoch 179/2000
# 400/400 [==============================] - 0s 25us/step - loss: 185.2148 - mean_squared_error: 185.2148 - val_loss: 162.0180 - val_mean_squared_error: 162.0180
# Epoch 180/2000
# 400/400 [==============================] - 0s 25us/step - loss: 159.5964 - mean_squared_error: 159.5963 - val_loss: 197.3065 - val_mean_squared_error: 197.3065
# Epoch 181/2000
# 400/400 [==============================] - 0s 40us/step - loss: 137.5652 - mean_squared_error: 137.5652 - val_loss: 210.1342 - val_mean_squared_error: 210.1342
# Epoch 182/2000
# 400/400 [==============================] - 0s 30us/step - loss: 153.3706 - mean_squared_error: 153.3706 - val_loss: 161.9319 - val_mean_squared_error: 161.9319
# Epoch 183/2000
# 400/400 [==============================] - 0s 22us/step - loss: 168.8779 - mean_squared_error: 168.8779 - val_loss: 212.1560 - val_mean_squared_error: 212.1560
# Epoch 184/2000
# 400/400 [==============================] - 0s 22us/step - loss: 159.6158 - mean_squared_error: 159.6158 - val_loss: 338.1987 - val_mean_squared_error: 338.1988
# Epoch 185/2000
# 400/400 [==============================] - 0s 22us/step - loss: 176.4090 - mean_squared_error: 176.4090 - val_loss: 166.6432 - val_mean_squared_error: 166.6432
# Epoch 186/2000
# 400/400 [==============================] - 0s 27us/step - loss: 179.5215 - mean_squared_error: 179.5214 - val_loss: 342.2699 - val_mean_squared_error: 342.2699
# Epoch 187/2000
# 400/400 [==============================] - 0s 25us/step - loss: 158.1551 - mean_squared_error: 158.1551 - val_loss: 151.3158 - val_mean_squared_error: 151.3158
# Epoch 188/2000
# 400/400 [==============================] - 0s 27us/step - loss: 217.0179 - mean_squared_error: 217.0179 - val_loss: 198.6684 - val_mean_squared_error: 198.6684
# Epoch 189/2000
# 400/400 [==============================] - 0s 25us/step - loss: 180.9122 - mean_squared_error: 180.9122 - val_loss: 214.8925 - val_mean_squared_error: 214.8925
# Epoch 190/2000
# 400/400 [==============================] - 0s 25us/step - loss: 169.8930 - mean_squared_error: 169.8931 - val_loss: 164.0375 - val_mean_squared_error: 164.0375
# Epoch 191/2000
# 400/400 [==============================] - 0s 25us/step - loss: 190.0813 - mean_squared_error: 190.0813 - val_loss: 333.0191 - val_mean_squared_error: 333.0191
# Epoch 192/2000
# 400/400 [==============================] - 0s 25us/step - loss: 163.4012 - mean_squared_error: 163.4012 - val_loss: 183.7022 - val_mean_squared_error: 183.7022
# Epoch 193/2000
# 400/400 [==============================] - 0s 25us/step - loss: 171.7402 - mean_squared_error: 171.7402 - val_loss: 223.6156 - val_mean_squared_error: 223.6156
# Epoch 194/2000
# 400/400 [==============================] - 0s 22us/step - loss: 135.1953 - mean_squared_error: 135.1954 - val_loss: 182.0204 - val_mean_squared_error: 182.0204
# Epoch 195/2000
# 400/400 [==============================] - 0s 22us/step - loss: 133.1767 - mean_squared_error: 133.1767 - val_loss: 200.9252 - val_mean_squared_error: 200.9252
# Epoch 196/2000
# 400/400 [==============================] - 0s 30us/step - loss: 136.6990 - mean_squared_error: 136.6990 - val_loss: 176.7713 - val_mean_squared_error: 176.7713
# Epoch 197/2000
# 400/400 [==============================] - 0s 25us/step - loss: 134.2228 - mean_squared_error: 134.2227 - val_loss: 190.9508 - val_mean_squared_error: 190.9508
# Epoch 198/2000
# 400/400 [==============================] - 0s 25us/step - loss: 144.2562 - mean_squared_error: 144.2562 - val_loss: 215.6073 - val_mean_squared_error: 215.6073
# Epoch 199/2000
# 400/400 [==============================] - 0s 25us/step - loss: 141.3037 - mean_squared_error: 141.3037 - val_loss: 162.7686 - val_mean_squared_error: 162.7686
# Epoch 200/2000
# 400/400 [==============================] - ETA: 0s - loss: 131.0115 - mean_squared_error: 131.01 - 0s 27us/step - loss: 132.0999 - mean_squared_error: 132.0999 - val_loss: 202.2584 - val_mean_squared_error: 202.2584
# Epoch 201/2000
# 400/400 [==============================] - 0s 22us/step - loss: 138.2677 - mean_squared_error: 138.2678 - val_loss: 172.3516 - val_mean_squared_error: 172.3516
# Epoch 202/2000
# 400/400 [==============================] - 0s 25us/step - loss: 150.5489 - mean_squared_error: 150.5489 - val_loss: 162.8480 - val_mean_squared_error: 162.8480
# Epoch 203/2000
# 400/400 [==============================] - 0s 25us/step - loss: 168.7501 - mean_squared_error: 168.7502 - val_loss: 317.0731 - val_mean_squared_error: 317.0731
# Epoch 204/2000
# 400/400 [==============================] - 0s 27us/step - loss: 144.2481 - mean_squared_error: 144.2481 - val_loss: 163.6133 - val_mean_squared_error: 163.6133
# Epoch 205/2000
# 400/400 [==============================] - 0s 27us/step - loss: 170.6444 - mean_squared_error: 170.6445 - val_loss: 345.9919 - val_mean_squared_error: 345.9919
# Epoch 206/2000
# 400/400 [==============================] - 0s 27us/step - loss: 149.3035 - mean_squared_error: 149.3035 - val_loss: 153.5000 - val_mean_squared_error: 153.5000
# Epoch 207/2000
# 400/400 [==============================] - 0s 25us/step - loss: 141.9003 - mean_squared_error: 141.9003 - val_loss: 256.5293 - val_mean_squared_error: 256.5293
# Epoch 208/2000
# 400/400 [==============================] - ETA: 0s - loss: 129.1385 - mean_squared_error: 129.13 - 0s 27us/step - loss: 134.6043 - mean_squared_error: 134.6043 - val_loss: 174.9653 - val_mean_squared_error: 174.9653
# Epoch 209/2000
# 400/400 [==============================] - 0s 27us/step - loss: 143.0507 - mean_squared_error: 143.0507 - val_loss: 157.5160 - val_mean_squared_error: 157.5160
# Epoch 210/2000
# 400/400 [==============================] - 0s 25us/step - loss: 147.9496 - mean_squared_error: 147.9496 - val_loss: 278.7809 - val_mean_squared_error: 278.7809
# Epoch 211/2000
# 400/400 [==============================] - 0s 22us/step - loss: 148.5911 - mean_squared_error: 148.5911 - val_loss: 170.0874 - val_mean_squared_error: 170.0873
# Epoch 212/2000
# 400/400 [==============================] - 0s 22us/step - loss: 138.3141 - mean_squared_error: 138.3141 - val_loss: 148.7095 - val_mean_squared_error: 148.7095
# Epoch 213/2000
# 400/400 [==============================] - 0s 25us/step - loss: 162.7758 - mean_squared_error: 162.7757 - val_loss: 298.1726 - val_mean_squared_error: 298.1726
# Epoch 214/2000
# 400/400 [==============================] - 0s 22us/step - loss: 176.0548 - mean_squared_error: 176.0547 - val_loss: 179.5037 - val_mean_squared_error: 179.5037
# Epoch 215/2000
# 400/400 [==============================] - 0s 25us/step - loss: 160.3252 - mean_squared_error: 160.3252 - val_loss: 269.8355 - val_mean_squared_error: 269.8355
# Epoch 216/2000
# 400/400 [==============================] - 0s 25us/step - loss: 171.3259 - mean_squared_error: 171.3259 - val_loss: 176.7894 - val_mean_squared_error: 176.7894
# Epoch 217/2000
# 400/400 [==============================] - 0s 22us/step - loss: 150.9982 - mean_squared_error: 150.9982 - val_loss: 311.4404 - val_mean_squared_error: 311.4404
# Epoch 218/2000
# 400/400 [==============================] - 0s 25us/step - loss: 140.7680 - mean_squared_error: 140.7680 - val_loss: 194.9443 - val_mean_squared_error: 194.9443
# Epoch 219/2000
# 400/400 [==============================] - 0s 25us/step - loss: 145.6046 - mean_squared_error: 145.6046 - val_loss: 151.8645 - val_mean_squared_error: 151.8645
# Epoch 220/2000
# 400/400 [==============================] - 0s 22us/step - loss: 143.0943 - mean_squared_error: 143.0943 - val_loss: 185.1825 - val_mean_squared_error: 185.1825
# Epoch 221/2000
# 400/400 [==============================] - 0s 27us/step - loss: 135.3356 - mean_squared_error: 135.3356 - val_loss: 169.5952 - val_mean_squared_error: 169.5952
# Epoch 222/2000
# 400/400 [==============================] - 0s 25us/step - loss: 151.7441 - mean_squared_error: 151.7441 - val_loss: 166.6591 - val_mean_squared_error: 166.6591
# Epoch 223/2000
# 400/400 [==============================] - 0s 22us/step - loss: 163.5476 - mean_squared_error: 163.5477 - val_loss: 288.3052 - val_mean_squared_error: 288.3052
# Epoch 224/2000
# 400/400 [==============================] - 0s 25us/step - loss: 143.0171 - mean_squared_error: 143.0171 - val_loss: 172.0664 - val_mean_squared_error: 172.0665
# Epoch 225/2000
# 400/400 [==============================] - 0s 25us/step - loss: 160.0036 - mean_squared_error: 160.0036 - val_loss: 279.0188 - val_mean_squared_error: 279.0188
# Epoch 226/2000
# 400/400 [==============================] - 0s 22us/step - loss: 145.7857 - mean_squared_error: 145.7857 - val_loss: 150.4072 - val_mean_squared_error: 150.4072
# Epoch 227/2000
# 400/400 [==============================] - 0s 25us/step - loss: 146.6393 - mean_squared_error: 146.6393 - val_loss: 183.6871 - val_mean_squared_error: 183.6871
# Epoch 228/2000
# 400/400 [==============================] - 0s 22us/step - loss: 158.1493 - mean_squared_error: 158.1493 - val_loss: 250.4520 - val_mean_squared_error: 250.4520
# Epoch 229/2000
# 400/400 [==============================] - 0s 27us/step - loss: 146.4029 - mean_squared_error: 146.4030 - val_loss: 195.5267 - val_mean_squared_error: 195.5267
# Epoch 230/2000
# 400/400 [==============================] - 0s 25us/step - loss: 161.4370 - mean_squared_error: 161.4370 - val_loss: 163.3546 - val_mean_squared_error: 163.3546
# Epoch 231/2000
# 400/400 [==============================] - 0s 30us/step - loss: 147.7380 - mean_squared_error: 147.7380 - val_loss: 230.1324 - val_mean_squared_error: 230.1324
# Epoch 232/2000
# 400/400 [==============================] - 0s 27us/step - loss: 163.1194 - mean_squared_error: 163.1194 - val_loss: 155.4642 - val_mean_squared_error: 155.4642
# Epoch 233/2000
# 400/400 [==============================] - 0s 25us/step - loss: 152.2889 - mean_squared_error: 152.2889 - val_loss: 228.7797 - val_mean_squared_error: 228.7796
# Epoch 234/2000
# 400/400 [==============================] - 0s 22us/step - loss: 136.1772 - mean_squared_error: 136.1772 - val_loss: 175.7247 - val_mean_squared_error: 175.7247
# Epoch 235/2000
# 400/400 [==============================] - 0s 25us/step - loss: 134.3835 - mean_squared_error: 134.3835 - val_loss: 298.9092 - val_mean_squared_error: 298.9091
# Epoch 236/2000
# 400/400 [==============================] - 0s 25us/step - loss: 146.2384 - mean_squared_error: 146.2384 - val_loss: 176.2996 - val_mean_squared_error: 176.2996
# Epoch 237/2000
# 400/400 [==============================] - 0s 22us/step - loss: 151.8340 - mean_squared_error: 151.8340 - val_loss: 182.3777 - val_mean_squared_error: 182.3777
# Epoch 238/2000
# 400/400 [==============================] - 0s 30us/step - loss: 168.1550 - mean_squared_error: 168.1550 - val_loss: 224.4081 - val_mean_squared_error: 224.4081
# Epoch 239/2000
# 400/400 [==============================] - 0s 27us/step - loss: 185.8950 - mean_squared_error: 185.8950 - val_loss: 161.6128 - val_mean_squared_error: 161.6128
# Epoch 240/2000
# 400/400 [==============================] - 0s 25us/step - loss: 177.7591 - mean_squared_error: 177.7591 - val_loss: 350.3287 - val_mean_squared_error: 350.3287
# Epoch 241/2000
# 400/400 [==============================] - 0s 25us/step - loss: 167.2042 - mean_squared_error: 167.2042 - val_loss: 195.0345 - val_mean_squared_error: 195.0345
# Epoch 242/2000
# 400/400 [==============================] - 0s 25us/step - loss: 162.2789 - mean_squared_error: 162.2789 - val_loss: 244.4533 - val_mean_squared_error: 244.4533
# Epoch 243/2000
# 400/400 [==============================] - 0s 27us/step - loss: 161.4313 - mean_squared_error: 161.4313 - val_loss: 168.3720 - val_mean_squared_error: 168.3720
# Epoch 244/2000
# 400/400 [==============================] - 0s 22us/step - loss: 142.7321 - mean_squared_error: 142.7321 - val_loss: 279.7868 - val_mean_squared_error: 279.7868
# Epoch 245/2000
# 400/400 [==============================] - 0s 25us/step - loss: 137.5392 - mean_squared_error: 137.5392 - val_loss: 157.2409 - val_mean_squared_error: 157.2409
# Epoch 246/2000
# 400/400 [==============================] - 0s 22us/step - loss: 139.9228 - mean_squared_error: 139.9228 - val_loss: 197.4397 - val_mean_squared_error: 197.4397
# Epoch 247/2000
# 400/400 [==============================] - 0s 25us/step - loss: 134.5121 - mean_squared_error: 134.5121 - val_loss: 160.5289 - val_mean_squared_error: 160.5289
# Epoch 248/2000
# 400/400 [==============================] - 0s 27us/step - loss: 135.9767 - mean_squared_error: 135.9767 - val_loss: 218.1497 - val_mean_squared_error: 218.1497
# Epoch 249/2000
# 400/400 [==============================] - 0s 27us/step - loss: 162.5754 - mean_squared_error: 162.5754 - val_loss: 182.3919 - val_mean_squared_error: 182.3919
# Epoch 250/2000
# 400/400 [==============================] - 0s 25us/step - loss: 152.5666 - mean_squared_error: 152.5666 - val_loss: 198.6152 - val_mean_squared_error: 198.6152
# Epoch 251/2000
# 400/400 [==============================] - 0s 22us/step - loss: 148.7440 - mean_squared_error: 148.7440 - val_loss: 182.2748 - val_mean_squared_error: 182.2748
# Epoch 252/2000
# 400/400 [==============================] - 0s 25us/step - loss: 131.6403 - mean_squared_error: 131.6403 - val_loss: 178.7547 - val_mean_squared_error: 178.7547
# Epoch 253/2000
# 400/400 [==============================] - 0s 22us/step - loss: 137.5727 - mean_squared_error: 137.5727 - val_loss: 176.0684 - val_mean_squared_error: 176.0684
# Epoch 254/2000
# 400/400 [==============================] - 0s 22us/step - loss: 145.7569 - mean_squared_error: 145.7569 - val_loss: 163.7950 - val_mean_squared_error: 163.7950
# Epoch 255/2000
# 400/400 [==============================] - 0s 25us/step - loss: 146.5585 - mean_squared_error: 146.5585 - val_loss: 248.7868 - val_mean_squared_error: 248.7868
# Epoch 256/2000
# 400/400 [==============================] - 0s 22us/step - loss: 141.3016 - mean_squared_error: 141.3017 - val_loss: 171.7559 - val_mean_squared_error: 171.7559
# Epoch 257/2000
# 400/400 [==============================] - 0s 22us/step - loss: 135.5348 - mean_squared_error: 135.5348 - val_loss: 216.5230 - val_mean_squared_error: 216.5230
# Epoch 258/2000
# 400/400 [==============================] - 0s 25us/step - loss: 157.1789 - mean_squared_error: 157.1789 - val_loss: 196.9238 - val_mean_squared_error: 196.9238
# Epoch 259/2000
# 400/400 [==============================] - 0s 25us/step - loss: 148.3309 - mean_squared_error: 148.3309 - val_loss: 160.3374 - val_mean_squared_error: 160.3374
# Epoch 260/2000
# 400/400 [==============================] - 0s 22us/step - loss: 138.8192 - mean_squared_error: 138.8192 - val_loss: 221.6414 - val_mean_squared_error: 221.6414
# Epoch 261/2000
# 400/400 [==============================] - 0s 30us/step - loss: 129.9487 - mean_squared_error: 129.9487 - val_loss: 160.9265 - val_mean_squared_error: 160.9265
# Epoch 262/2000
# 400/400 [==============================] - 0s 25us/step - loss: 147.6724 - mean_squared_error: 147.6724 - val_loss: 252.8543 - val_mean_squared_error: 252.8543
# Epoch 263/2000
# 400/400 [==============================] - 0s 25us/step - loss: 154.6775 - mean_squared_error: 154.6775 - val_loss: 165.2827 - val_mean_squared_error: 165.2827
# Epoch 264/2000
# 400/400 [==============================] - 0s 25us/step - loss: 149.6828 - mean_squared_error: 149.6828 - val_loss: 168.1581 - val_mean_squared_error: 168.1581
# Epoch 265/2000
# 400/400 [==============================] - 0s 25us/step - loss: 150.3346 - mean_squared_error: 150.3347 - val_loss: 289.2577 - val_mean_squared_error: 289.2577
# Epoch 266/2000
# 400/400 [==============================] - 0s 25us/step - loss: 148.7313 - mean_squared_error: 148.7312 - val_loss: 150.5045 - val_mean_squared_error: 150.5045
# Epoch 267/2000
# 400/400 [==============================] - 0s 22us/step - loss: 134.5907 - mean_squared_error: 134.5907 - val_loss: 154.9887 - val_mean_squared_error: 154.9886
# Epoch 268/2000
# 400/400 [==============================] - 0s 25us/step - loss: 141.0129 - mean_squared_error: 141.0129 - val_loss: 158.7306 - val_mean_squared_error: 158.7306
# Epoch 269/2000
# 400/400 [==============================] - 0s 25us/step - loss: 161.1553 - mean_squared_error: 161.1553 - val_loss: 210.2790 - val_mean_squared_error: 210.2790
# Epoch 270/2000
# 400/400 [==============================] - 0s 22us/step - loss: 148.0891 - mean_squared_error: 148.0891 - val_loss: 160.3657 - val_mean_squared_error: 160.3657
# Epoch 271/2000
# ...
# Epoch 1910/2000
# 400/400 [==============================] - 0s 27us/step - loss: 97.3302 - mean_squared_error: 97.3302 - val_loss: 102.7461 - val_mean_squared_error: 102.7461
# Epoch 1911/2000
# 400/400 [==============================] - 0s 25us/step - loss: 98.7759 - mean_squared_error: 98.7759 - val_loss: 111.6820 - val_mean_squared_error: 111.6820
# Epoch 1912/2000
# 400/400 [==============================] - 0s 25us/step - loss: 91.7852 - mean_squared_error: 91.7852 - val_loss: 137.0256 - val_mean_squared_error: 137.0256
# Epoch 1913/2000
# 400/400 [==============================] - 0s 27us/step - loss: 94.2455 - mean_squared_error: 94.2455 - val_loss: 129.4746 - val_mean_squared_error: 129.4746
# Epoch 1914/2000
# 400/400 [==============================] - 0s 27us/step - loss: 92.4377 - mean_squared_error: 92.4377 - val_loss: 126.2919 - val_mean_squared_error: 126.2919
# Epoch 1915/2000
# 400/400 [==============================] - 0s 30us/step - loss: 93.1585 - mean_squared_error: 93.1585 - val_loss: 139.7752 - val_mean_squared_error: 139.7752
# Epoch 1916/2000
# 400/400 [==============================] - 0s 25us/step - loss: 96.9262 - mean_squared_error: 96.9262 - val_loss: 96.0865 - val_mean_squared_error: 96.0865
# Epoch 1917/2000
# 400/400 [==============================] - 0s 27us/step - loss: 105.9353 - mean_squared_error: 105.9353 - val_loss: 104.0167 - val_mean_squared_error: 104.0167
# Epoch 1918/2000
# 400/400 [==============================] - 0s 27us/step - loss: 94.0394 - mean_squared_error: 94.0394 - val_loss: 131.4602 - val_mean_squared_error: 131.4602
# Epoch 1919/2000
# 400/400 [==============================] - 0s 27us/step - loss: 95.0161 - mean_squared_error: 95.0162 - val_loss: 117.0836 - val_mean_squared_error: 117.0836
# Epoch 1920/2000
# 400/400 [==============================] - 0s 25us/step - loss: 96.1810 - mean_squared_error: 96.1810 - val_loss: 95.6831 - val_mean_squared_error: 95.6831
# Epoch 1921/2000
# 400/400 [==============================] - 0s 32us/step - loss: 102.3212 - mean_squared_error: 102.3213 - val_loss: 125.4567 - val_mean_squared_error: 125.4567
# Epoch 1922/2000
# 400/400 [==============================] - 0s 30us/step - loss: 96.0186 - mean_squared_error: 96.0186 - val_loss: 130.9174 - val_mean_squared_error: 130.9174
# Epoch 1923/2000
# 400/400 [==============================] - 0s 27us/step - loss: 92.9094 - mean_squared_error: 92.9094 - val_loss: 138.6489 - val_mean_squared_error: 138.6489
# Epoch 1924/2000
# 400/400 [==============================] - 0s 25us/step - loss: 98.5326 - mean_squared_error: 98.5325 - val_loss: 97.6413 - val_mean_squared_error: 97.6413
# Epoch 1925/2000
# 400/400 [==============================] - 0s 27us/step - loss: 99.9079 - mean_squared_error: 99.9079 - val_loss: 104.0306 - val_mean_squared_error: 104.0306
# Epoch 1926/2000
# 400/400 [==============================] - 0s 27us/step - loss: 96.3103 - mean_squared_error: 96.3103 - val_loss: 171.3860 - val_mean_squared_error: 171.3860
# Epoch 1927/2000
# 400/400 [==============================] - 0s 27us/step - loss: 97.6889 - mean_squared_error: 97.6889 - val_loss: 180.3694 - val_mean_squared_error: 180.3694
# Epoch 1928/2000
# 400/400 [==============================] - 0s 27us/step - loss: 101.3248 - mean_squared_error: 101.3248 - val_loss: 110.0751 - val_mean_squared_error: 110.0751
# Epoch 1929/2000
# 400/400 [==============================] - 0s 27us/step - loss: 92.8464 - mean_squared_error: 92.8464 - val_loss: 130.1750 - val_mean_squared_error: 130.1750
# Epoch 1930/2000
# 400/400 [==============================] - 0s 27us/step - loss: 91.0653 - mean_squared_error: 91.0653 - val_loss: 150.1608 - val_mean_squared_error: 150.1608
# Epoch 1931/2000
# 400/400 [==============================] - 0s 27us/step - loss: 104.7510 - mean_squared_error: 104.7510 - val_loss: 146.4816 - val_mean_squared_error: 146.4816
# Epoch 1932/2000
# 400/400 [==============================] - 0s 30us/step - loss: 96.4991 - mean_squared_error: 96.4991 - val_loss: 106.3990 - val_mean_squared_error: 106.3990
# Epoch 1933/2000
# 400/400 [==============================] - 0s 30us/step - loss: 95.4003 - mean_squared_error: 95.4003 - val_loss: 118.1897 - val_mean_squared_error: 118.1897
# Epoch 1934/2000
# 400/400 [==============================] - 0s 25us/step - loss: 93.9415 - mean_squared_error: 93.9415 - val_loss: 152.9925 - val_mean_squared_error: 152.9925
# Epoch 1935/2000
# 400/400 [==============================] - 0s 25us/step - loss: 105.1667 - mean_squared_error: 105.1667 - val_loss: 104.7316 - val_mean_squared_error: 104.7316
# Epoch 1936/2000
# 400/400 [==============================] - 0s 25us/step - loss: 95.8467 - mean_squared_error: 95.8467 - val_loss: 98.1078 - val_mean_squared_error: 98.1078
# Epoch 1937/2000
# 400/400 [==============================] - 0s 27us/step - loss: 108.2884 - mean_squared_error: 108.2884 - val_loss: 124.0119 - val_mean_squared_error: 124.0119
# Epoch 1938/2000
# 400/400 [==============================] - 0s 27us/step - loss: 107.1090 - mean_squared_error: 107.1090 - val_loss: 229.9789 - val_mean_squared_error: 229.9789
# Epoch 1939/2000
# 400/400 [==============================] - 0s 25us/step - loss: 110.1923 - mean_squared_error: 110.1923 - val_loss: 193.9835 - val_mean_squared_error: 193.9835
# Epoch 1940/2000
# 400/400 [==============================] - 0s 30us/step - loss: 99.5939 - mean_squared_error: 99.5939 - val_loss: 115.8596 - val_mean_squared_error: 115.8596
# Epoch 1941/2000
# 400/400 [==============================] - 0s 27us/step - loss: 96.9781 - mean_squared_error: 96.9781 - val_loss: 100.5801 - val_mean_squared_error: 100.5800
# Epoch 1942/2000
# 400/400 [==============================] - 0s 32us/step - loss: 97.3178 - mean_squared_error: 97.3178 - val_loss: 99.3864 - val_mean_squared_error: 99.3864
# Epoch 1943/2000
# 400/400 [==============================] - 0s 32us/step - loss: 94.2500 - mean_squared_error: 94.2500 - val_loss: 117.3534 - val_mean_squared_error: 117.3534
# Epoch 1944/2000
# 400/400 [==============================] - 0s 27us/step - loss: 91.8619 - mean_squared_error: 91.8619 - val_loss: 117.7694 - val_mean_squared_error: 117.7694
# Epoch 1945/2000
# 400/400 [==============================] - 0s 30us/step - loss: 96.1788 - mean_squared_error: 96.1788 - val_loss: 142.1055 - val_mean_squared_error: 142.1055
# Epoch 1946/2000
# 400/400 [==============================] - 0s 27us/step - loss: 98.6846 - mean_squared_error: 98.6845 - val_loss: 133.4195 - val_mean_squared_error: 133.4195
# Epoch 1947/2000
# 400/400 [==============================] - 0s 27us/step - loss: 101.8544 - mean_squared_error: 101.8544 - val_loss: 94.9559 - val_mean_squared_error: 94.9559
# Epoch 1948/2000
# 400/400 [==============================] - 0s 25us/step - loss: 100.9586 - mean_squared_error: 100.9586 - val_loss: 108.5505 - val_mean_squared_error: 108.5505
# Epoch 1949/2000
# 400/400 [==============================] - 0s 27us/step - loss: 94.5140 - mean_squared_error: 94.5140 - val_loss: 130.5869 - val_mean_squared_error: 130.5869
# Epoch 1950/2000
# 400/400 [==============================] - 0s 27us/step - loss: 92.6358 - mean_squared_error: 92.6358 - val_loss: 150.2825 - val_mean_squared_error: 150.2825
# Epoch 1951/2000
# 400/400 [==============================] - 0s 30us/step - loss: 96.0273 - mean_squared_error: 96.0273 - val_loss: 95.7933 - val_mean_squared_error: 95.7933
# Epoch 1952/2000
# 400/400 [==============================] - 0s 25us/step - loss: 110.6239 - mean_squared_error: 110.6239 - val_loss: 136.0295 - val_mean_squared_error: 136.0296
# Epoch 1953/2000
# 400/400 [==============================] - 0s 27us/step - loss: 103.3301 - mean_squared_error: 103.3301 - val_loss: 181.2982 - val_mean_squared_error: 181.2982
# Epoch 1954/2000
# 400/400 [==============================] - 0s 27us/step - loss: 108.2118 - mean_squared_error: 108.2118 - val_loss: 196.7871 - val_mean_squared_error: 196.7871
# Epoch 1955/2000
# 400/400 [==============================] - 0s 27us/step - loss: 113.7537 - mean_squared_error: 113.7537 - val_loss: 162.3638 - val_mean_squared_error: 162.3638
# Epoch 1956/2000
# 400/400 [==============================] - 0s 27us/step - loss: 102.6316 - mean_squared_error: 102.6316 - val_loss: 124.0946 - val_mean_squared_error: 124.0946
# Epoch 1957/2000
# 400/400 [==============================] - 0s 25us/step - loss: 95.6049 - mean_squared_error: 95.6049 - val_loss: 127.2062 - val_mean_squared_error: 127.2062
# Epoch 1958/2000
# 400/400 [==============================] - 0s 27us/step - loss: 93.2928 - mean_squared_error: 93.2928 - val_loss: 127.8409 - val_mean_squared_error: 127.8409
# Epoch 1959/2000
# 400/400 [==============================] - 0s 27us/step - loss: 93.9266 - mean_squared_error: 93.9266 - val_loss: 148.8291 - val_mean_squared_error: 148.8291
# Epoch 1960/2000
# 400/400 [==============================] - 0s 27us/step - loss: 98.9487 - mean_squared_error: 98.9487 - val_loss: 98.6389 - val_mean_squared_error: 98.6389
# Epoch 1961/2000
# 400/400 [==============================] - 0s 27us/step - loss: 95.9805 - mean_squared_error: 95.9804 - val_loss: 103.8229 - val_mean_squared_error: 103.8229
# Epoch 1962/2000
# 400/400 [==============================] - 0s 30us/step - loss: 95.4979 - mean_squared_error: 95.4979 - val_loss: 148.7306 - val_mean_squared_error: 148.7306
# Epoch 1963/2000
# 400/400 [==============================] - 0s 27us/step - loss: 100.2508 - mean_squared_error: 100.2508 - val_loss: 168.8693 - val_mean_squared_error: 168.8693
# Epoch 1964/2000
# 400/400 [==============================] - 0s 27us/step - loss: 97.8832 - mean_squared_error: 97.8832 - val_loss: 120.5383 - val_mean_squared_error: 120.5384
# Epoch 1965/2000
# 400/400 [==============================] - 0s 25us/step - loss: 91.8473 - mean_squared_error: 91.8473 - val_loss: 116.5119 - val_mean_squared_error: 116.5120
# Epoch 1966/2000
# 400/400 [==============================] - 0s 25us/step - loss: 94.1641 - mean_squared_error: 94.1641 - val_loss: 98.7225 - val_mean_squared_error: 98.7225
# Epoch 1967/2000
# 400/400 [==============================] - 0s 27us/step - loss: 104.9885 - mean_squared_error: 104.9885 - val_loss: 118.3596 - val_mean_squared_error: 118.3596
# Epoch 1968/2000
# 400/400 [==============================] - 0s 27us/step - loss: 104.7430 - mean_squared_error: 104.7430 - val_loss: 166.8675 - val_mean_squared_error: 166.8675
# Epoch 1969/2000
# 400/400 [==============================] - 0s 27us/step - loss: 95.0227 - mean_squared_error: 95.0227 - val_loss: 152.0949 - val_mean_squared_error: 152.0948
# Epoch 1970/2000
# 400/400 [==============================] - 0s 25us/step - loss: 97.0190 - mean_squared_error: 97.0190 - val_loss: 188.8960 - val_mean_squared_error: 188.8960
# Epoch 1971/2000
# 400/400 [==============================] - 0s 30us/step - loss: 97.9629 - mean_squared_error: 97.9629 - val_loss: 130.3943 - val_mean_squared_error: 130.3943
# Epoch 1972/2000
# 400/400 [==============================] - 0s 30us/step - loss: 93.6481 - mean_squared_error: 93.6481 - val_loss: 100.4244 - val_mean_squared_error: 100.4244
# Epoch 1973/2000
# 400/400 [==============================] - 0s 27us/step - loss: 106.4877 - mean_squared_error: 106.4877 - val_loss: 130.6627 - val_mean_squared_error: 130.6627
# Epoch 1974/2000
# 400/400 [==============================] - 0s 25us/step - loss: 109.5996 - mean_squared_error: 109.5996 - val_loss: 194.8945 - val_mean_squared_error: 194.8945
# Epoch 1975/2000
# 400/400 [==============================] - 0s 25us/step - loss: 103.2207 - mean_squared_error: 103.2207 - val_loss: 114.0722 - val_mean_squared_error: 114.0722
# Epoch 1976/2000
# 400/400 [==============================] - 0s 32us/step - loss: 94.0869 - mean_squared_error: 94.0869 - val_loss: 122.3362 - val_mean_squared_error: 122.3362
# Epoch 1977/2000
# 400/400 [==============================] - 0s 25us/step - loss: 92.6306 - mean_squared_error: 92.6306 - val_loss: 109.0840 - val_mean_squared_error: 109.0840
# Epoch 1978/2000
# 400/400 [==============================] - 0s 27us/step - loss: 94.2516 - mean_squared_error: 94.2516 - val_loss: 109.8679 - val_mean_squared_error: 109.8680
# Epoch 1979/2000
# 400/400 [==============================] - 0s 27us/step - loss: 94.7176 - mean_squared_error: 94.7176 - val_loss: 119.5955 - val_mean_squared_error: 119.5955
# Epoch 1980/2000
# 400/400 [==============================] - 0s 25us/step - loss: 93.1522 - mean_squared_error: 93.1522 - val_loss: 207.2581 - val_mean_squared_error: 207.2581
# Epoch 1981/2000
# 400/400 [==============================] - 0s 30us/step - loss: 106.8585 - mean_squared_error: 106.8585 - val_loss: 107.2555 - val_mean_squared_error: 107.2555
# Epoch 1982/2000
# 400/400 [==============================] - 0s 30us/step - loss: 94.5020 - mean_squared_error: 94.5020 - val_loss: 140.1008 - val_mean_squared_error: 140.1008
# Epoch 1983/2000
# 400/400 [==============================] - 0s 27us/step - loss: 95.5846 - mean_squared_error: 95.5846 - val_loss: 114.2695 - val_mean_squared_error: 114.2695
# Epoch 1984/2000
# 400/400 [==============================] - 0s 25us/step - loss: 92.5736 - mean_squared_error: 92.5736 - val_loss: 113.7849 - val_mean_squared_error: 113.7849
# Epoch 1985/2000
# 400/400 [==============================] - 0s 25us/step - loss: 94.3886 - mean_squared_error: 94.3886 - val_loss: 102.7356 - val_mean_squared_error: 102.7356
# Epoch 1986/2000
# 400/400 [==============================] - 0s 27us/step - loss: 96.0792 - mean_squared_error: 96.0792 - val_loss: 125.6581 - val_mean_squared_error: 125.6581
# Epoch 1987/2000
# 400/400 [==============================] - 0s 25us/step - loss: 92.7869 - mean_squared_error: 92.7869 - val_loss: 123.0360 - val_mean_squared_error: 123.0360
# Epoch 1988/2000
# 400/400 [==============================] - 0s 30us/step - loss: 93.3882 - mean_squared_error: 93.3882 - val_loss: 108.8749 - val_mean_squared_error: 108.8749
# Epoch 1989/2000
# 400/400 [==============================] - 0s 25us/step - loss: 96.5899 - mean_squared_error: 96.5899 - val_loss: 102.9125 - val_mean_squared_error: 102.9125
# Epoch 1990/2000
# 400/400 [==============================] - 0s 30us/step - loss: 97.8483 - mean_squared_error: 97.8483 - val_loss: 132.4774 - val_mean_squared_error: 132.4774
# Epoch 1991/2000
# 400/400 [==============================] - 0s 27us/step - loss: 95.0569 - mean_squared_error: 95.0569 - val_loss: 164.8366 - val_mean_squared_error: 164.8366
# Epoch 1992/2000
# 400/400 [==============================] - 0s 30us/step - loss: 93.5753 - mean_squared_error: 93.5753 - val_loss: 120.0440 - val_mean_squared_error: 120.0440
# Epoch 1993/2000
# 400/400 [==============================] - 0s 25us/step - loss: 94.1241 - mean_squared_error: 94.1241 - val_loss: 144.1270 - val_mean_squared_error: 144.1270
# Epoch 1994/2000
# 400/400 [==============================] - 0s 25us/step - loss: 91.2093 - mean_squared_error: 91.2093 - val_loss: 131.0267 - val_mean_squared_error: 131.0267
# Epoch 1995/2000
# 400/400 [==============================] - 0s 27us/step - loss: 91.2319 - mean_squared_error: 91.2319 - val_loss: 124.1710 - val_mean_squared_error: 124.1710
# Epoch 1996/2000
# 400/400 [==============================] - 0s 27us/step - loss: 92.5992 - mean_squared_error: 92.5992 - val_loss: 111.2583 - val_mean_squared_error: 111.2583
# Epoch 1997/2000
# 400/400 [==============================] - 0s 27us/step - loss: 93.2992 - mean_squared_error: 93.2992 - val_loss: 116.8602 - val_mean_squared_error: 116.8602
# Epoch 1998/2000
# 400/400 [==============================] - 0s 27us/step - loss: 91.8899 - mean_squared_error: 91.8899 - val_loss: 139.7546 - val_mean_squared_error: 139.7545
# Epoch 1999/2000
# 400/400 [==============================] - 0s 30us/step - loss: 103.3330 - mean_squared_error: 103.3330 - val_loss: 98.4399 - val_mean_squared_error: 98.4399
# Epoch 2000/2000
# 400/400 [==============================] - 0s 27us/step - loss: 101.7676 - mean_squared_error: 101.7676 - val_loss: 111.2068 - val_mean_squared_error: 111.2068

# %% [markdown]
# I'll plot the accuract of the training and test sets to see how things went:

# %%
    plt.rcParams.update({'font.size': 15})

fig = plt.figure(figsize=(20, 6))

model_mse = fig.add_subplot(1, 2, 1)
plt.plot(results.history['mean_squared_error'])
model_mse.title.set_text("model_mse")
model_mse.set(xlabel="epochs")
model_mse.set(Ylabel="error")

valid_mse = fig.add_subplot(1, 2, 2)
plt.plot(results.history['val_mean_squared_error'], color="r")
valid_mse.title.set_text("valid_mse")
valid_mse.set(xlabel="epochs")
valid_mse.set(Ylabel="error")

plt.show()

# %% [markdown]
# I'll load the saved "best" model to see how good it is. I'm setting the "compile" hyperparameter to false becasue I don't need to do any training of the model, just testing of how well it works. This prevents an error.

# %%
model = keras.models.load_model("./Models/proj_7_best_model.h5", compile=False)

prediction = model.predict(test_features)
error = sklearn.metrics.mean_squared_error(prediction, test_labels)
print(error)
# Out:
# 106.89112761706114

# %% [markdown]
# All right, so it looks like my error is around 110 most of the time. While it's not great, I can expect an answer within +/- 10cm of the truth when estimating height.
